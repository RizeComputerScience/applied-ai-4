# %%
"""
Unit 6: Agent Battle Royale Tournament
"""

from battle_royale import run_battle_royale
import webbrowser
import os

print("🎮 Starting Unit 6 Tournament...")
print("This will generate:")
print("  1. tournament_results.json (raw data)")
print("  2. tournament_dashboard.html (interactive explorer)")
print("  3. tournament_bracket.png (bracket image)")
print("\n" + "="*70 + "\n")

# Run tournament
bracket_champ, rr_tournament, all_agents = run_battle_royale(
    folder_path="student_agents",
    bracket_rounds=100,
    rr_rounds=100,
    num_tournaments=3,
    save_bracket=True
)

print("\n🎉 Done! Opening dashboard in browser...")

# Automatically open the HTML file in default browser
html_file = "tournament_dashboard.html"
if os.path.exists(html_file):
    file_path = os.path.abspath(html_file)
    webbrowser.open('file://' + file_path)
    print(f"✅ Dashboard opened in browser!")
    print(f"   If it didn't open, manually open: {html_file}")
else:
    print(f"❌ Could not find {html_file}")
# Out:
# 🎮 Starting Unit 6 Tournament...
# This will generate:
#   1. tournament_results.json (raw data)
#   2. tournament_dashboard.html (interactive explorer)
#   3. tournament_bracket.png (bracket image)
#
# ======================================================================
#
#
# ████████╗██╗  ██╗███████╗    ██╗   ██╗██╗  ████████╗██╗███╗   ███╗ █████╗ ████████╗███████╗
# ╚══██╔══╝██║  ██║██╔════╝    ██║   ██║██║  ╚══██╔══╝██║████╗ ████║██╔══██╗╚══██╔══╝██╔════╝
#    ██║   ███████║█████╗      ██║   ██║██║     ██║   ██║██╔████╔██║███████║   ██║   █████╗
#    ██║   ██╔══██║██╔══╝      ██║   ██║██║     ██║   ██║██║╚██╔╝██║██╔══██║   ██║   ██╔══╝
#    ██║   ██║  ██║███████╗    ╚██████╔╝███████╗██║   ██║██║ ╚═╝ ██║██║  ██║   ██║   ███████╗
#    ╚═╝   ╚═╝  ╚═╝╚══════╝     ╚═════╝ ╚══════╝╚═╝   ╚═╝╚═╝     ╚═╝╚═╝  ╚═╝   ╚═╝   ╚══════╝
#
#  █████╗  ██████╗ ███████╗███╗   ██╗████████╗    ██████╗  █████╗ ████████╗████████╗██╗     ███████╗
# ██╔══██╗██╔════╝ ██╔════╝████╗  ██║╚══██╔══╝    ██╔══██╗██╔══██╗╚══██╔══╝╚══██╔══╝██║     ██╔════╝
# ███████║██║  ███╗█████╗  ██╔██╗ ██║   ██║       ██████╔╝███████║   ██║      ██║   ██║     █████╗
# ██╔══██║██║   ██║██╔══╝  ██║╚██╗██║   ██║       ██╔══██╗██╔══██║   ██║      ██║   ██║     ██╔══╝
# ██║  ██║╚██████╔╝███████╗██║ ╚████║   ██║       ██████╔╝██║  ██║   ██║      ██║   ███████╗███████╗
# ╚═╝  ╚═╝ ╚═════╝ ╚══════╝╚═╝  ╚═══╝   ╚═╝       ╚═════╝ ╚═╝  ╚═╝   ╚═╝      ╚═╝   ╚══════╝╚══════╝
#                                     UNIT 6: THE SHOWDOWN
#
# 📂 Loading student agents from: student_agents
# ======================================================================
#
# ✅ Trust Builder                  by Alex Brown
# ✅ Relationship Keeper            by Alex Singh
# ✅ Risk Manager                   by Bailey Gonzalez
# ✅ Stable Cooperator              by Casey Thomas
# ✅ Balanced Trader                by Casey Wong
# ✅ Betrayal Detector              by Elliot Lopez
# ✅ Game Theory Expert             by Elliot Wong
# ✅ Strategic Dove                 by Finley Lee
# ✅ Equilibrium Finder             by Hayden Gonzalez
# ✅ Quick Retaliator               by Hayden Smith
# ✅ Cooperative Hawk               by Jesse Garcia
# ✅ Dynamic Responder              by Jordan Thomas
# ✅ Profit Maximizer               by Logan Brown
# ✅ Reputation Defender            by Morgan Chen
# ✅ Chaos Agent                    by Morgan Lee
# ✅ Adaptive Survivor              by Morgan Smith
# ✅ Unnamed Agent                  by my_tournament_agent
# ✅ Ruthless Optimizer             by Quinn Brown
# ✅ Pattern Matcher                by Quinn Martin
# ✅ Nash Seeker                    by Taylor Gonzalez
# ✅ Opportunist Prime              by Taylor Jackson
#
# 📊 Total agents loaded: 21
# ======================================================================
#
#
# ======================================================================
# 🏆 BRACKET TOURNAMENT: SINGLE ELIMINATION
# ======================================================================
#
# 🎲 21 agents randomly seeded
# 🏟️  5 rounds until champion
#
# ======================================================================
# ⚔️  ROUND 1
# ======================================================================
#
# ✅ Opportunist Prime         defeats Pattern Matcher           (214-99)
# ✅ Unnamed Agent             defeats Equilibrium Finder        (207-97)
# ✅ Profit Maximizer          defeats Dynamic Responder         (156-131)
# ✅ Betrayal Detector         defeats Stable Cooperator         (171-131)
# ✅ Strategic Dove            defeats Ruthless Optimizer        (134-109)
# ✅ Reputation Defender       defeats Game Theory Expert        (169-114)
# 🤝 TIE: Relationship Keeper vs Nash Seeker (107-107) - SUDDEN DEATH!
# ⚡ Nash Seeker               wins sudden death! (12-22)
# ✅ Balanced Trader           defeats Quick Retaliator          (139-134)
# ✅ Adaptive Survivor         defeats Chaos Agent               (162-87)
# ✅ Trust Builder             defeats Cooperative Hawk          (131-121)
# 👋 Risk Manager              gets a bye (advances automatically)
#
# ======================================================================
# ⚔️  ROUND 2
# ======================================================================
#
# ✅ Unnamed Agent             defeats Opportunist Prime         (136-101)
# ✅ Profit Maximizer          defeats Betrayal Detector         (146-91)
# ✅ Strategic Dove            defeats Reputation Defender       (135-120)
# ✅ Nash Seeker               defeats Balanced Trader           (120-105)
# ✅ Adaptive Survivor         defeats Trust Builder             (126-101)
# 👋 Risk Manager              gets a bye (advances automatically)
#
# ======================================================================
# ⚔️  ROUND 3
# ======================================================================
#
# ✅ Unnamed Agent             defeats Profit Maximizer          (128-103)
# ✅ Strategic Dove            defeats Nash Seeker               (126-101)
# ✅ Adaptive Survivor         defeats Risk Manager              (121-101)
#
# ======================================================================
# ⚔️  ROUND 4
# ======================================================================
#
# ✅ Strategic Dove            defeats Unnamed Agent             (109-104)
# 👋 Adaptive Survivor         gets a bye (advances automatically)
#
# ======================================================================
# 🏆 FINALS
# ======================================================================
#
# ✅ Adaptive Survivor         defeats Strategic Dove            (120-95)
#
# ======================================================================
# 🎉 TOURNAMENT CHAMPION 🎉
# ======================================================================
#
# 👑 Adaptive Survivor
#    by Morgan Smith
#
#    Survived 5 rounds of elimination!
# ======================================================================
# /Users/douglasdahl/Desktop/AAI IV/battle_royale.py:332: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/douglasdahl/Desktop/AAI IV/battle_royale.py:332: UserWarning: Glyph 128081 (\N{CROWN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/douglasdahl/Desktop/AAI IV/battle_royale.py:333: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
# /Users/douglasdahl/Desktop/AAI IV/battle_royale.py:333: UserWarning: Glyph 128081 (\N{CROWN}) missing from font(s) DejaVu Sans.
#   plt.savefig(filename, dpi=300, bbox_inches='tight', facecolor='white')
# ✅ Bracket saved to: tournament_bracket.png
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 127942 (\N{TROPHY}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/lib/python3.13/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128081 (\N{CROWN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ======================================================================
# 📊 COMPREHENSIVE ROUND-ROBIN TOURNAMENT
# ======================================================================
#
# Every agent plays every other agent 3 time(s)
# Each match: 100 rounds
# Total matches: 1260
# ======================================================================
#
# Running 3 tournament(s) with 21 agents...
#
# Tournament 1/3
#
# Tournament 2/3
#
# Tournament 3/3
# Tournament complete!
#
# ======================================================================
# 🏆 FINAL COMPREHENSIVE RANKINGS
# ======================================================================
#
# 🥇  1. Unnamed Agent                 : 9,544 points
# 🥈  2. Relationship Keeper           : 9,189 points
# 🥉  3. Stable Cooperator             : 9,036 points
#     4. Chaos Agent                   : 8,783 points
#     5. Adaptive Survivor             : 8,768 points  👑 BRACKET CHAMPION
#     6. Reputation Defender           : 8,748 points
#     7. Strategic Dove                : 8,575 points
#     8. Nash Seeker                   : 8,516 points
#     9. Profit Maximizer              : 8,482 points
#    10. Trust Builder                 : 8,473 points
#    11. Balanced Trader               : 8,458 points
#    12. Opportunist Prime             : 8,237 points
#    13. Cooperative Hawk              : 8,124 points
#    14. Risk Manager                  : 8,113 points
#    15. Betrayal Detector             : 7,979 points
#    16. Ruthless Optimizer            : 7,979 points
#    17. Quick Retaliator              : 7,967 points
#    18. Pattern Matcher               : 7,805 points
#    19. Game Theory Expert            : 7,715 points
#    20. Dynamic Responder             : 7,709 points
#    21. Equilibrium Finder            : 7,347 points
#
# ======================================================================
# 📈 DETAILED PERFORMANCE STATISTICS
# ======================================================================
#
# Agent                           Wins  Win Rate  Avg Score
# ----------------------------------------------------------------------
# Unnamed Agent                     98    81.7%      158.1
# Relationship Keeper              106    88.3%      151.4
# Stable Cooperator                  6     5.0%      156.6
# Chaos Agent                       59    49.2%      147.3
# Adaptive Survivor                115    95.8%      146.4
# Reputation Defender               58    48.3%      142.0
# Strategic Dove                    98    81.7%      143.0
# Nash Seeker                       92    76.7%      142.0
# Profit Maximizer                  74    61.7%      140.0
# Trust Builder                     82    68.3%      139.8
# Balanced Trader                   68    56.7%      141.1
# Opportunist Prime                 67    55.8%      140.1
# Cooperative Hawk                  43    35.8%      134.5
# Risk Manager                      51    42.5%      136.5
# Betrayal Detector                 37    30.8%      132.4
# Ruthless Optimizer                39    32.5%      133.1
# Quick Retaliator                  46    38.3%      134.2
# Pattern Matcher                    6     5.0%      130.4
# Game Theory Expert                18    15.0%      129.5
# Dynamic Responder                 36    30.0%      130.1
# Equilibrium Finder                10     8.3%      121.9
#
# ======================================================================
# 🤔 BRACKET vs ROUND-ROBIN COMPARISON
# ======================================================================
#
# 👑 Bracket Champion:      Adaptive Survivor
#    Round-Robin Rank:      #5
#
# 🏆 Round-Robin Champion:  Unnamed Agent
#
# 💡 Lesson: Single elimination is exciting but can be random!
#    The most consistent performer wins the comprehensive tournament.
#
# ======================================================================
# 🏅 SUPERLATIVE AWARDS
# ======================================================================
#
# 🤝 MOST COOPERATIVE: Unnamed Agent
#    Average score: 158.1 (achieves mutual cooperation)
#
# ⚔️  MOST AGGRESSIVE: Adaptive Survivor
#    Wins: 115 (95.8% win rate)
#
# 📊 MOST CONSISTENT: Equilibrium Finder
#    Score std dev: 29.6 (very predictable)
#
# 🎯 BIGGEST UPSET: Equilibrium Finder
#    Defeated Stable Cooperator (ranked 18 spots higher)
#
# 💥 GLASS CANNON: Chaos Agent
#    Scored 310 points vs Stable Cooperator in single game
#
# 🎖️  PARTICIPATION TROPHY: Equilibrium Finder
#    Finished last but showed up! (7,347 points)
# ======================================================================
#
# ======================================================================
# 👥 ALL STUDENT AGENTS - FIND YOURS!
# ======================================================================
#
# Student                   Agent Name                       Rank      Score
# --------------------------------------------------------------------------------
# 🥇 my_tournament_agent       Unnamed Agent                     1      9,544
# 🥈 Alex Singh                Relationship Keeper               2      9,189
# 🥉 Casey Thomas              Stable Cooperator                 3      9,036
#    Morgan Lee                Chaos Agent                       4      8,783
#    Morgan Smith              Adaptive Survivor                 5      8,768
#    Morgan Chen               Reputation Defender               6      8,748
#    Finley Lee                Strategic Dove                    7      8,575
#    Taylor Gonzalez           Nash Seeker                       8      8,516
#    Logan Brown               Profit Maximizer                  9      8,482
#    Alex Brown                Trust Builder                    10      8,473
#    Casey Wong                Balanced Trader                  11      8,458
#    Taylor Jackson            Opportunist Prime                12      8,237
#    Jesse Garcia              Cooperative Hawk                 13      8,124
#    Bailey Gonzalez           Risk Manager                     14      8,113
#    Elliot Lopez              Betrayal Detector                15      7,979
#    Quinn Brown               Ruthless Optimizer               16      7,979
#    Hayden Smith              Quick Retaliator                 17      7,967
#    Quinn Martin              Pattern Matcher                  18      7,805
#    Elliot Wong               Game Theory Expert               19      7,715
#    Jordan Thomas             Dynamic Responder                20      7,709
#    Hayden Gonzalez           Equilibrium Finder               21      7,347
#
# ======================================================================
# 💾 EXPORTING TOURNAMENT DATA
# ======================================================================
#
# ✅ Tournament data exported to: tournament_results.json
#    Total agents: 21
#    Total matches: 1260
#    File size: 214.4 KB
#
# ======================================================================
# 🌐 GENERATING INTERACTIVE DASHBOARD
# ======================================================================
#
# ✅ Interactive dashboard generated: tournament_dashboard.html
#    Open this file in your browser to explore results!
#    Features:
#      - Searchable tables
#      - Tabbed interface
#      - Bracket visualization
#      - Superlative awards
#
# 🎉 Done! Opening dashboard in browser...
# ✅ Dashboard opened in browser!
#    If it didn't open, manually open: tournament_dashboard.html

# %%
# ============================================================================
# REFLECTION QUESTIONS
# ============================================================================

print("\n" + "="*70)
print("📝 REFLECTION QUESTIONS FOR YOUR WRITEUP")
print("="*70)
print("""
Look at the "ALL STUDENT AGENTS" table above to find your ranking.

1. Tournament Performance Analysis
   - What was your agent's final rank?
   - How did you perform in bracket vs. round-robin?
   - Were the results similar or different? Why might that be?

2. Strategy Analysis
   - Look at the top 3 agents. What strategies do they use?
   - Compare them to your agent's strategy (your evolved genes)
   - What made the winning strategies successful?

3. Bracket vs. Round-Robin
   - Was the Bracket Champion the same as Round-Robin Champion?
   - If different, what does this teach you about tournament formats?
   - Which format better reflects true agent quality? Why?

4. Superlative Awards
   - Which superlative award did your agent win (if any)?
   - What trade-offs do different strategies make?
   - Would you rather have high win rate or high total score?

5. Generalization Lesson
   - Your agent was trained on 10 random opponents in Unit 5
   - It competed against 20+ agents here (most unseen)
   - How did this affect your agent's performance?
   - What would you change if you could redesign for THIS environment?

6. Game Theory Insights
   - Is there a "best" strategy that beats everyone?
   - Why or why not? (Hint: Think about opponent diversity)
   - What real-world situations mirror this tournament dynamic?

SUBMISSION: Write a 1-2 page reflection answering these questions.
Include your rank, total score, and what you learned about
evolutionary optimization and game theory.
""")

print("\n" + "="*70)
print("🎉 THANK YOU FOR PARTICIPATING!")
print("="*70)
