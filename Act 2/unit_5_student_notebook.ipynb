# %%
"""
Unit 5: Evolving Your IPD Agent with Genetic Algorithms
========================================================

In Unit 4, you hand-coded agent strategies like Tit-for-Tat.
In Unit 5, you'll use evolution to DISCOVER strategies automatically.

By the end, you'll have an evolved agent saved as a JSON file for the tournament!
"""

# ============================================================================
# SETUP: Import everything from previous units
# ============================================================================

import random
import numpy as np
import json
import matplotlib.pyplot as plt
from agents import Agent, INVEST, UNDERCUT
from game_engine import Game, Tournament

# Import all hand-coded agents from Unit 4
from agents import (
    AlwaysInvestAgent, AlwaysUndercutAgent, TitForTatAgent,
    GrimTriggerAgent, PavlovAgent, TitForTwoTatsAgent,
    GenerousTitForTatAgent, AdaptiveAgent, RandomAgent,
    SuspiciousTitForTatAgent, GradualAgent, HardMajorityAgent,
    SoftMajorityAgent, ProberAgent
)

print("✅ Imports complete!")
# Out:
# ✅ Imports complete!

# %%
# ============================================================================
# PART 1: THE EVOLVABLE AGENT (PROVIDED - Read but don't modify)
# ============================================================================

class EvolvableAgent(Agent):
    """
    An agent whose strategy is controlled by 6 genes (numbers from 0 to 1).
    
    Think of genes as "strategy dials" you can tune:
    
    Gene[0] - Initial Cooperation (0=hostile start, 1=friendly start)
    Gene[1] - Cooperation Response (if opponent cooperates, how likely to cooperate back?)
    Gene[2] - Defection Response (if opponent defects, how likely to defect back?)
    Gene[3] - Forgiveness (after retaliation, chance to forgive)
    Gene[4] - Memory Length (0=last 1 round, 1=last 10 rounds)
    Gene[5] - Retaliation Threshold (what % of defections triggers retaliation)
    """
    
    def __init__(self, genes=None, name="Evolved Agent"):
        if genes is None:
            # Create random genes if none provided
            genes = [random.random() for _ in range(6)]
        
        self.genes = genes
        super().__init__(name, f"Genes: [{', '.join([f'{g:.2f}' for g in genes])}]")
    
    def choose_action(self) -> bool:
        """Decision logic based on genes - SIMPLIFIED FOR LEARNING"""
        
        # First 3 rounds: use initial cooperation gene
        if self.round_num < 3:
            return random.random() < self.genes[0]
        
        # Calculate memory window (gene[4])
        memory_length = max(1, int(self.genes[4] * 10) + 1)
        recent_history = self.history[-memory_length:]
        
        # Calculate opponent's recent COOPERATION rate (not defection!)
        cooperation_rate = sum(recent_history) / len(recent_history)
        
        # If opponent is mostly cooperating, reciprocate
        if cooperation_rate >= 0.5:
            return random.random() < self.genes[1]  # gene[1] = cooperate response
        
        # If opponent is mostly defecting, retaliate or forgive
        else:
            # Retaliate with probability gene[2]
            if random.random() < self.genes[2]:
                return UNDERCUT
            # Or forgive with probability gene[3]
            elif random.random() < self.genes[3]:
                return INVEST
            else:
                return UNDERCUT

# %%
# ============================================================================
# PART 2: DEFINE THE OPPONENT ECOSYSTEM
# ============================================================================

# ============================================================================
# EXPANDED OPPONENT POOL
# ============================================================================

# Full pool of all possible opponents
full_opponent_pool = [
    # Cooperative agents
    AlwaysInvestAgent(),
    TitForTatAgent(),
    GrimTriggerAgent(),
    PavlovAgent(),
    TitForTwoTatsAgent(),
    GenerousTitForTatAgent(),
    AdaptiveAgent(),
    
    # Aggressive agents
    AlwaysUndercutAgent(),
    SuspiciousTitForTatAgent(),
    
    # Sophisticated agents
    GradualAgent(),
    ProberAgent(),
    
    # Majority-based agents
    HardMajorityAgent(),
    SoftMajorityAgent(),
    
    # Random agents with different cooperation levels
    RandomAgent(0.9),
    RandomAgent(0.7),
    RandomAgent(0.5),
    RandomAgent(0.3),
    RandomAgent(0.1),
]

print(f"\n📚 Full opponent library: {len(full_opponent_pool)} agents available")

# For initial evolution, randomly sample opponents
opponent_pool = random.sample(full_opponent_pool, 10)

print(f"🎲 Randomly selected {len(opponent_pool)} opponents for this evolution:")
for i, opp in enumerate(opponent_pool, 1):
    print(f"  {i:2d}. {opp.name:25s} - {opp.description}")
print("="*70)
# Out:
# 📚 Full opponent library: 18 agents available
# 🎲 Randomly selected 10 opponents for this evolution:
#    1. Random (0.9)              - Randomly invests 90% of the time
#    2. Random (0.1)              - Randomly invests 10% of the time
#    3. Hard Majority             - Defects if opponent defects >50% of time
#    4. Adaptive                  - Adapts to opponent's cooperation rate
#    5. Random (0.7)              - Randomly invests 70% of the time
#    6. Grim Trigger              - Invests until betrayed once, then undercuts forever
#    7. Pavlov                    - Win-Stay-Lose-Shift strategy
#    8. Tit-for-Tat               - Starts friendly, then copies opponent
#    9. Tit-for-Two-Tats          - Tolerates one betrayal, retaliates after two
#   10. Always Invest             - Always invests in market development
# ======================================================================

# %%
# ============================================================================
# PART 3: GENETIC ALGORITHM FUNCTIONS (YOUR TODO!)
# ============================================================================

def initialize_population(pop_size):
    """
    Create initial population of random agents.
    
    Args:
        pop_size: Number of agents in population
    
    Returns:
        List of EvolvableAgent objects with random genes
    """
    population = []
    for i in range(pop_size):
        agent = EvolvableAgent(name=f"Agent_{i}")
        population.append(agent)
    return population


def evaluate_fitness(agent, opponents, num_rounds=50):
    """
    Measure how good an agent is by playing against all opponents.
    
    Args:
        agent: The EvolvableAgent to evaluate
        opponents: List of opponent agents to play against
        num_rounds: Number of rounds per game
    
    Returns:
        Float: Average score per game (higher is better)
    """
    total_score = 0
    num_games = 0
    
    for opponent in opponents:
        game = Game(agent, opponent, num_rounds=num_rounds)
        score, _ = game.play()
        total_score += score
        num_games += 1
    
    avg_score = total_score / num_games
    return avg_score


def tournament_selection(population, fitnesses, tournament_size=3):
    """
    Select parents using tournament selection.
    
    Tournament selection:
    1. Pick tournament_size random individuals
    2. Choose the one with best fitness
    3. Repeat until we have pop_size selected parents
    
    Args:
        population: List of agents
        fitnesses: List of fitness scores (parallel to population)
        tournament_size: How many agents compete in each tournament
    
    Returns:
        List of selected agents (same length as population)
    """
    selected = []
    
    for _ in range(len(population)):
        # Pick random contestants
        contestants_idx = random.sample(range(len(population)), tournament_size)
        
        # Find the one with best fitness
        best_idx = max(contestants_idx, key=lambda i: fitnesses[i])
        
        # Add winner to selected (make a copy of genes)
        winner_genes = population[best_idx].genes.copy()
        selected.append(EvolvableAgent(genes=winner_genes))
    
    return selected


def crossover_and_mutate(parent1, parent2, mutation_rate=0.15):
    """
    Create a child from two parents using crossover and mutation.
    
    Crossover (single-point):
    1. Pick a random split point (1 to 5)
    2. Take genes before split from parent1
    3. Take genes after split from parent2
    
    Mutation:
    1. For each gene, with probability=mutation_rate:
    2. Add Gaussian noise (mean=0, std=0.2)
    3. Clip gene to stay in range [0, 1]
    
    Args:
        parent1: First parent EvolvableAgent
        parent2: Second parent EvolvableAgent
        mutation_rate: Probability of mutating each gene
    
    Returns:
        New EvolvableAgent (the child)
    """
    # Crossover
    crossover_point = random.randint(1, 5)  # Random split between 1 and 5
    child_genes = (parent1.genes[:crossover_point] + 
                   parent2.genes[crossover_point:])
    
    # Mutation
    for i in range(len(child_genes)):
        if random.random() < mutation_rate:
            # Add random noise
            child_genes[i] += random.gauss(0, 0.2)
            # Keep gene in valid range [0, 1]
            child_genes[i] = max(0.0, min(1.0, child_genes[i]))
    
    return EvolvableAgent(genes=child_genes)


def evolve(generations=25, pop_size=20, opponents=None, mutation_rate=0.15, elitism=2):
    """
    Run the genetic algorithm to evolve an agent.
    
    Process:
    1. Create initial random population
    2. For each generation:
       a. Evaluate fitness of all agents
       b. Select parents via tournament selection
       c. Create children via crossover & mutation
       d. Keep best agents (elitism)
    3. Return the best agent found
    
    Args:
        generations: Number of generations to evolve
        pop_size: Size of population
        opponents: List of opponents to evaluate against
        mutation_rate: Probability of gene mutation
        elitism: Number of best agents to keep unchanged
    
    Returns:
        Best EvolvableAgent found
    """
    if opponents is None:
        opponents = opponent_pool
    
    print(f"\n🧬 EVOLUTION STARTING")
    print(f"{'='*70}")
    print(f"Population: {pop_size} | Generations: {generations} | Mutation: {mutation_rate}")
    print(f"Opponents: {len(opponents)} | Elitism: {elitism}")
    print(f"{'='*70}\n")
    
    # Track statistics
    best_fitness_history = []
    avg_fitness_history = []
    
    # Initialize population
    population = initialize_population(pop_size)
    
    best_overall_agent = None
    best_overall_fitness = -float('inf')
    
    # Evolution loop
    for gen in range(generations):
        # Evaluate fitness for all agents
        fitnesses = []
        for agent in population:
            fitness = evaluate_fitness(agent, opponents, num_rounds=50)
            fitnesses.append(fitness)
        
        # Track best and average
        # Track best and average
        best_fitness = max(fitnesses)
        avg_fitness = sum(fitnesses) / len(fitnesses)
        best_fitness_history.append(best_overall_fitness)
        avg_fitness_history.append(avg_fitness)

        # Sanity check: best fitness should never decrease (elitism guarantee)
        if gen > 0 and best_fitness < best_fitness_history[gen-1]:
            print(f"⚠️  WARNING: Best fitness decreased from {best_fitness_history[gen-1]:.2f} to {best_fitness:.2f}")
            print(f"    This suggests a bug in elitism or fitness evaluation!")
        
        # Track best agent ever seen
        # Track best agent ever seen
        best_idx = fitnesses.index(best_fitness)
        if best_fitness > best_overall_fitness:
            best_overall_fitness = best_fitness
            # CRITICAL: Make a deep copy so genes don't get mutated later
            best_overall_agent = EvolvableAgent(genes=population[best_idx].genes.copy())
        
        # Print progress
        print(f"Gen {gen+1:3d}/{generations}: "
              f"Best={best_fitness:6.2f} | Avg={avg_fitness:6.2f} | "
              f"Genes={[f'{g:.2f}' for g in population[best_idx].genes]}")
        
        # Create next generation (unless this is the last generation)
        if gen < generations - 1:
            # Sort population by fitness for elitism
            sorted_indices = sorted(range(len(fitnesses)), 
                                  key=lambda i: fitnesses[i], 
                                  reverse=True)
            
            # Keep elite agents (top performers)
            next_population = []
            for i in range(elitism):
                elite_genes = population[sorted_indices[i]].genes.copy()
                next_population.append(EvolvableAgent(genes=elite_genes))
            
            # Selection
            selected = tournament_selection(population, fitnesses)
            
            # Create offspring to fill rest of population
            while len(next_population) < pop_size:
                parent1, parent2 = random.sample(selected, 2)
                child = crossover_and_mutate(parent1, parent2, mutation_rate)
                next_population.append(child)
            
            population = next_population
    
    print(f"\n{'='*70}")
    print(f"✅ EVOLUTION COMPLETE!")
    print(f"🏆 Best fitness achieved: {best_overall_fitness:.2f}")
    print(f"{'='*70}\n")
    
    # Plot evolution progress
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, generations+1), best_fitness_history, 
             label='Best Fitness', linewidth=2, color='green', marker='o')
    plt.plot(range(1, generations+1), avg_fitness_history, 
             label='Average Fitness', linewidth=2, color='blue', marker='s', alpha=0.7)
    plt.xlabel('Generation', fontsize=12)
    plt.ylabel('Fitness (Avg Score per Game)', fontsize=12)
    plt.title('Evolution Progress', fontsize=14, fontweight='bold')
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    return best_overall_agent

# %%
# ============================================================================
# PART 4: RUN EVOLUTION! (Student executes this)
# ============================================================================

print("\n" + "="*70)
print("🚀 TIME TO EVOLVE YOUR AGENT!")
print("="*70)

# TODO: Experiment with these parameters to find the best agent!
my_evolved_agent = evolve(
    generations=100,       # Try: 20, 30, 50
    pop_size=30,         # Try: 15, 20, 30
    opponents=opponent_pool,
    mutation_rate=0.1,  # Try: 0.1, 0.15, 0.2
    elitism=2            # Keep top 2 agents each generation
)

print(f"\n🎉 Your evolved agent's final genes:")
print(f"   {my_evolved_agent.genes}")
# Out:
# ======================================================================
# 🚀 TIME TO EVOLVE YOUR AGENT!
# ======================================================================
#
# 🧬 EVOLUTION STARTING
# ======================================================================
# Population: 30 | Generations: 100 | Mutation: 0.1
# Opponents: 10 | Elitism: 2
# ======================================================================
#
# Gen   1/100: Best=133.60 | Avg=121.30 | Genes=['0.43', '0.62', '0.16', '0.70', '0.36', '0.12']
# Gen   2/100: Best=134.80 | Avg=123.06 | Genes=['0.98', '0.78', '0.98', '0.51', '0.35', '0.89']
# ⚠️  WARNING: Best fitness decreased from 133.60 to 133.40
#     This suggests a bug in elitism or fitness evaluation!
# Gen   3/100: Best=133.40 | Avg=125.95 | Genes=['0.78', '0.79', '0.71', '0.78', '0.36', '0.99']
# ⚠️  WARNING: Best fitness decreased from 134.80 to 134.20
#     This suggests a bug in elitism or fitness evaluation!
# Gen   4/100: Best=134.20 | Avg=125.78 | Genes=['0.52', '0.63', '0.71', '0.73', '0.36', '0.17']
# Gen   5/100: Best=134.80 | Avg=126.13 | Genes=['0.69', '0.72', '0.71', '0.78', '0.36', '0.93']
# Gen   6/100: Best=137.30 | Avg=128.89 | Genes=['0.35', '0.62', '0.49', '0.75', '0.36', '0.38']
# Gen   7/100: Best=137.80 | Avg=127.81 | Genes=['0.52', '0.63', '0.98', '1.00', '0.36', '0.96']
# ⚠️  WARNING: Best fitness decreased from 137.30 to 134.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen   8/100: Best=134.80 | Avg=124.84 | Genes=['1.00', '0.72', '0.71', '0.50', '0.33', '0.93']
# ⚠️  WARNING: Best fitness decreased from 137.80 to 135.90
#     This suggests a bug in elitism or fitness evaluation!
# Gen   9/100: Best=135.90 | Avg=125.59 | Genes=['1.00', '0.72', '0.71', '0.50', '0.33', '0.93']
# Gen  10/100: Best=138.30 | Avg=125.48 | Genes=['1.00', '0.91', '0.73', '0.32', '0.36', '0.12']
# ⚠️  WARNING: Best fitness decreased from 137.80 to 136.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  11/100: Best=136.10 | Avg=127.50 | Genes=['1.00', '1.00', '0.96', '1.00', '0.36', '0.12']
# ⚠️  WARNING: Best fitness decreased from 138.30 to 136.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  12/100: Best=136.60 | Avg=131.12 | Genes=['1.00', '0.78', '1.00', '1.00', '0.53', '0.39']
# ⚠️  WARNING: Best fitness decreased from 138.30 to 136.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  13/100: Best=136.10 | Avg=129.59 | Genes=['1.00', '1.00', '0.96', '1.00', '0.36', '0.12']
# ⚠️  WARNING: Best fitness decreased from 138.30 to 137.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  14/100: Best=137.30 | Avg=129.88 | Genes=['1.00', '0.72', '0.96', '1.00', '0.53', '0.39']
# ⚠️  WARNING: Best fitness decreased from 138.30 to 137.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  15/100: Best=137.60 | Avg=130.88 | Genes=['1.00', '0.73', '1.00', '1.00', '0.53', '0.00']
# Gen  16/100: Best=138.30 | Avg=132.28 | Genes=['1.00', '0.58', '1.00', '0.14', '0.53', '0.98']
# Gen  17/100: Best=138.30 | Avg=134.14 | Genes=['1.00', '1.00', '0.96', '1.00', '0.58', '0.39']
# Gen  18/100: Best=138.40 | Avg=135.85 | Genes=['1.00', '1.00', '0.96', '1.00', '0.42', '0.00']
# Gen  19/100: Best=138.60 | Avg=135.66 | Genes=['1.00', '1.00', '1.00', '1.00', '1.00', '0.58']
# Gen  20/100: Best=138.70 | Avg=135.40 | Genes=['1.00', '1.00', '1.00', '1.00', '0.83', '0.00']
# Gen  21/100: Best=139.00 | Avg=135.27 | Genes=['0.99', '1.00', '0.96', '1.00', '0.58', '0.12']
# ⚠️  WARNING: Best fitness decreased from 138.70 to 138.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  22/100: Best=138.00 | Avg=133.17 | Genes=['1.00', '1.00', '1.00', '1.00', '1.00', '0.12']
# ⚠️  WARNING: Best fitness decreased from 139.00 to 138.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  23/100: Best=138.30 | Avg=135.49 | Genes=['1.00', '1.00', '0.96', '1.00', '0.58', '0.12']
# ⚠️  WARNING: Best fitness decreased from 139.00 to 138.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  24/100: Best=138.30 | Avg=134.92 | Genes=['1.00', '1.00', '0.96', '1.00', '0.89', '0.00']
# ⚠️  WARNING: Best fitness decreased from 139.00 to 138.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  25/100: Best=138.60 | Avg=135.73 | Genes=['1.00', '1.00', '1.00', '1.00', '0.71', '0.12']
# Gen  26/100: Best=140.10 | Avg=136.11 | Genes=['0.92', '1.00', '0.96', '1.00', '1.00', '0.12']
# ⚠️  WARNING: Best fitness decreased from 139.00 to 138.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  27/100: Best=138.60 | Avg=134.91 | Genes=['1.00', '1.00', '0.96', '1.00', '0.83', '0.12']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 138.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  28/100: Best=138.10 | Avg=135.55 | Genes=['1.00', '1.00', '0.96', '1.00', '0.67', '0.07']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 139.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  29/100: Best=139.10 | Avg=135.22 | Genes=['1.00', '1.00', '0.96', '1.00', '0.67', '0.07']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 139.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  30/100: Best=139.60 | Avg=134.88 | Genes=['1.00', '1.00', '0.96', '1.00', '0.67', '0.30']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 138.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  31/100: Best=138.30 | Avg=136.25 | Genes=['1.00', '1.00', '1.00', '1.00', '0.95', '0.12']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 138.40
#     This suggests a bug in elitism or fitness evaluation!
# Gen  32/100: Best=138.40 | Avg=135.37 | Genes=['1.00', '1.00', '1.00', '1.00', '0.67', '0.12']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 138.90
#     This suggests a bug in elitism or fitness evaluation!
# Gen  33/100: Best=138.90 | Avg=135.45 | Genes=['1.00', '1.00', '1.00', '1.00', '0.95', '0.30']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 138.40
#     This suggests a bug in elitism or fitness evaluation!
# Gen  34/100: Best=138.40 | Avg=135.89 | Genes=['1.00', '1.00', '1.00', '1.00', '0.67', '0.35']
# Gen  35/100: Best=141.40 | Avg=135.49 | Genes=['1.00', '0.92', '1.00', '1.00', '0.58', '0.23']
# ⚠️  WARNING: Best fitness decreased from 140.10 to 138.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  36/100: Best=138.60 | Avg=134.59 | Genes=['1.00', '1.00', '1.00', '1.00', '0.42', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 138.70
#     This suggests a bug in elitism or fitness evaluation!
# Gen  37/100: Best=138.70 | Avg=135.91 | Genes=['1.00', '1.00', '1.00', '1.00', '0.58', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 138.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  38/100: Best=138.00 | Avg=135.19 | Genes=['1.00', '1.00', '1.00', '0.75', '0.58', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 138.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  39/100: Best=138.00 | Avg=134.67 | Genes=['1.00', '1.00', '1.00', '1.00', '0.58', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 138.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  40/100: Best=138.10 | Avg=135.83 | Genes=['1.00', '1.00', '1.00', '0.79', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.20
#     This suggests a bug in elitism or fitness evaluation!
# Gen  41/100: Best=139.20 | Avg=136.38 | Genes=['1.00', '1.00', '1.00', '0.75', '0.67', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  42/100: Best=139.00 | Avg=136.61 | Genes=['0.94', '1.00', '1.00', '1.00', '0.42', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 138.90
#     This suggests a bug in elitism or fitness evaluation!
# Gen  43/100: Best=138.90 | Avg=135.76 | Genes=['1.00', '1.00', '1.00', '0.79', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.40
#     This suggests a bug in elitism or fitness evaluation!
# Gen  44/100: Best=139.40 | Avg=136.28 | Genes=['1.00', '1.00', '0.97', '0.75', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  45/100: Best=139.60 | Avg=135.72 | Genes=['1.00', '1.00', '1.00', '0.87', '0.67', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  46/100: Best=139.50 | Avg=137.15 | Genes=['1.00', '1.00', '1.00', '0.79', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  47/100: Best=139.50 | Avg=136.20 | Genes=['1.00', '1.00', '1.00', '0.79', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.20
#     This suggests a bug in elitism or fitness evaluation!
# Gen  48/100: Best=139.20 | Avg=136.41 | Genes=['1.00', '1.00', '0.97', '0.75', '0.25', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  49/100: Best=139.80 | Avg=137.29 | Genes=['1.00', '1.00', '1.00', '0.52', '0.28', '0.22']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  50/100: Best=140.00 | Avg=136.51 | Genes=['1.00', '1.00', '1.00', '0.79', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.20
#     This suggests a bug in elitism or fitness evaluation!
# Gen  51/100: Best=139.20 | Avg=136.71 | Genes=['1.00', '1.00', '0.97', '0.52', '0.28', '0.47']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  52/100: Best=139.80 | Avg=137.08 | Genes=['1.00', '1.00', '1.00', '1.00', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  53/100: Best=139.30 | Avg=135.35 | Genes=['1.00', '1.00', '0.97', '0.44', '0.28', '0.22']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  54/100: Best=140.30 | Avg=136.99 | Genes=['1.00', '1.00', '1.00', '0.79', '0.28', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.20
#     This suggests a bug in elitism or fitness evaluation!
# Gen  55/100: Best=140.20 | Avg=137.03 | Genes=['1.00', '1.00', '1.00', '0.79', '0.28', '0.09']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  56/100: Best=139.80 | Avg=136.10 | Genes=['0.99', '1.00', '1.00', '1.00', '0.08', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  57/100: Best=139.60 | Avg=136.55 | Genes=['0.99', '1.00', '1.00', '1.00', '0.08', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.90
#     This suggests a bug in elitism or fitness evaluation!
# Gen  58/100: Best=139.90 | Avg=136.26 | Genes=['1.00', '1.00', '1.00', '0.97', '0.08', '0.29']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  59/100: Best=140.30 | Avg=137.75 | Genes=['1.00', '1.00', '1.00', '0.97', '0.08', '0.29']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  60/100: Best=140.60 | Avg=136.90 | Genes=['1.00', '1.00', '1.00', '0.79', '0.04', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  61/100: Best=140.50 | Avg=137.64 | Genes=['1.00', '1.00', '1.00', '0.79', '0.00', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  62/100: Best=140.50 | Avg=137.64 | Genes=['1.00', '1.00', '1.00', '0.79', '0.00', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  63/100: Best=140.10 | Avg=137.65 | Genes=['1.00', '1.00', '1.00', '0.79', '0.04', '0.23']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  64/100: Best=140.50 | Avg=138.17 | Genes=['0.84', '1.00', '1.00', '0.99', '0.03', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  65/100: Best=140.50 | Avg=136.87 | Genes=['1.00', '1.00', '1.00', '0.82', '0.04', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  66/100: Best=140.50 | Avg=136.81 | Genes=['0.84', '1.00', '1.00', '0.79', '0.05', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  67/100: Best=140.30 | Avg=135.88 | Genes=['1.00', '1.00', '1.00', '0.79', '0.04', '0.45']
# Gen  68/100: Best=141.40 | Avg=137.83 | Genes=['1.00', '1.00', '1.00', '0.82', '0.04', '0.14']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  69/100: Best=139.80 | Avg=137.94 | Genes=['1.00', '1.00', '1.00', '0.78', '0.04', '0.14']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  70/100: Best=140.10 | Avg=137.51 | Genes=['1.00', '1.00', '1.00', '0.78', '0.04', '0.14']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.70
#     This suggests a bug in elitism or fitness evaluation!
# Gen  71/100: Best=139.70 | Avg=136.96 | Genes=['1.00', '1.00', '1.00', '0.79', '0.04', '0.14']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.90
#     This suggests a bug in elitism or fitness evaluation!
# Gen  72/100: Best=140.90 | Avg=137.77 | Genes=['1.00', '1.00', '1.00', '0.78', '0.04', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  73/100: Best=140.00 | Avg=138.00 | Genes=['1.00', '1.00', '1.00', '0.78', '0.04', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  74/100: Best=139.60 | Avg=137.40 | Genes=['0.96', '1.00', '1.00', '0.79', '0.04', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  75/100: Best=140.00 | Avg=138.38 | Genes=['1.00', '1.00', '1.00', '0.78', '0.01', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.40
#     This suggests a bug in elitism or fitness evaluation!
# Gen  76/100: Best=140.40 | Avg=137.95 | Genes=['1.00', '1.00', '1.00', '0.78', '0.01', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  77/100: Best=140.60 | Avg=137.48 | Genes=['1.00', '1.00', '1.00', '0.78', '0.01', '0.13']
# Gen  78/100: Best=141.40 | Avg=137.74 | Genes=['1.00', '1.00', '1.00', '0.78', '0.04', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.70
#     This suggests a bug in elitism or fitness evaluation!
# Gen  79/100: Best=140.70 | Avg=133.64 | Genes=['1.00', '1.00', '1.00', '0.78', '0.04', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  80/100: Best=139.80 | Avg=136.15 | Genes=['1.00', '1.00', '1.00', '0.48', '0.04', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.90
#     This suggests a bug in elitism or fitness evaluation!
# Gen  81/100: Best=139.90 | Avg=137.18 | Genes=['1.00', '1.00', '1.00', '0.78', '0.09', '0.06']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  82/100: Best=139.80 | Avg=137.54 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.70
#     This suggests a bug in elitism or fitness evaluation!
# Gen  83/100: Best=139.70 | Avg=136.25 | Genes=['1.00', '1.00', '1.00', '1.00', '0.09', '0.06']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 141.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  84/100: Best=141.10 | Avg=137.69 | Genes=['1.00', '1.00', '1.00', '0.78', '0.04', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 141.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  85/100: Best=141.00 | Avg=137.91 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  86/100: Best=140.80 | Avg=137.36 | Genes=['1.00', '1.00', '1.00', '1.00', '0.04', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.70
#     This suggests a bug in elitism or fitness evaluation!
# Gen  87/100: Best=139.70 | Avg=137.68 | Genes=['1.00', '1.00', '0.99', '0.78', '0.04', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  88/100: Best=140.30 | Avg=138.41 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  89/100: Best=140.00 | Avg=136.20 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.00
#     This suggests a bug in elitism or fitness evaluation!
# Gen  90/100: Best=140.00 | Avg=137.30 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  91/100: Best=140.10 | Avg=138.14 | Genes=['1.00', '1.00', '1.00', '0.91', '0.00', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  92/100: Best=140.50 | Avg=137.84 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.90
#     This suggests a bug in elitism or fitness evaluation!
# Gen  93/100: Best=140.90 | Avg=138.01 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.13']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.30
#     This suggests a bug in elitism or fitness evaluation!
# Gen  94/100: Best=140.30 | Avg=137.32 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.04']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  95/100: Best=139.60 | Avg=138.12 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.32']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.60
#     This suggests a bug in elitism or fitness evaluation!
# Gen  96/100: Best=139.60 | Avg=137.63 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.10
#     This suggests a bug in elitism or fitness evaluation!
# Gen  97/100: Best=140.10 | Avg=137.88 | Genes=['1.00', '1.00', '0.95', '0.98', '0.00', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.50
#     This suggests a bug in elitism or fitness evaluation!
# Gen  98/100: Best=139.50 | Avg=137.54 | Genes=['1.00', '1.00', '1.00', '0.98', '0.00', '0.00']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 139.80
#     This suggests a bug in elitism or fitness evaluation!
# Gen  99/100: Best=139.80 | Avg=136.92 | Genes=['1.00', '1.00', '1.00', '0.86', '0.00', '0.08']
# ⚠️  WARNING: Best fitness decreased from 141.40 to 140.20
#     This suggests a bug in elitism or fitness evaluation!
# Gen 100/100: Best=140.20 | Avg=137.72 | Genes=['1.00', '1.00', '1.00', '1.00', '0.00', '0.00']
#
# ======================================================================
# ✅ EVOLUTION COMPLETE!
# 🏆 Best fitness achieved: 141.40
# ======================================================================
# 🎉 Your evolved agent's final genes:
#    [1.0, 0.9177957271603879, 1.0, 1.0, 0.5811340241250889, 0.22920528215876904]

# %%
# ============================================================================
# PART 5: TEST YOUR AGENT (Student runs benchmarks)
# ============================================================================

print("\n" + "="*70)
print("⚔️  TESTING YOUR AGENT AGAINST HAND-CODED OPPONENTS")
print("="*70 + "\n")

wins = 0
losses = 0
ties = 0

for opponent in opponent_pool:
    game = Game(my_evolved_agent, opponent, num_rounds=100)
    my_score, opp_score = game.play()
    
    if my_score > opp_score:
        result = "✅ WON"
        wins += 1
    elif my_score < opp_score:
        result = "❌ LOST"
        losses += 1
    else:
        result = "🤝 TIED"
        ties += 1
    
    print(f"vs {opponent.name:25s}: {my_score:3d} - {opp_score:3d}  {result}")

print(f"\n📊 Record: {wins} wins, {losses} losses, {ties} ties")
win_rate = wins / len(opponent_pool) * 100
print(f"🎯 Win Rate: {win_rate:.1f}%")
# Out:
# ======================================================================
# ⚔️  TESTING YOUR AGENT AGAINST HAND-CODED OPPONENTS
# ======================================================================
#
# vs Random (0.9)             : 286 - 286  🤝 TIED
# vs Random (0.1)             : 145 - 100  ✅ WON
# vs Hard Majority            : 320 - 270  ✅ WON
# vs Adaptive                 : 314 - 279  ✅ WON
# vs Random (0.7)             : 227 - 312  ❌ LOST
# vs Grim Trigger             : 120 - 135  ❌ LOST
# vs Pavlov                   : 242 - 217  ✅ WON
# vs Tit-for-Tat              : 293 - 293  🤝 TIED
# vs Tit-for-Two-Tats         : 316 - 276  ✅ WON
# vs Always Invest            : 308 - 288  ✅ WON
#
# 📊 Record: 6 wins, 2 losses, 2 ties
# 🎯 Win Rate: 60.0%

# %% [markdown]
# # Unit 5 Part 2: Benchmark Analysis
#
# **After running your initial evolution and benchmark tests, answer these questions.**
#
# ---
#
# ## Performance Summary
#
# Fill in your benchmark results:
#
# | Opponent | Result (W/L/T) | Your Score | Opp Score |
# |----------|----------------|------------|-----------|
# | Always Invest | | | |
# | Always Undercut | | | |
# | Tit-for-Tat | | | |
# | Grim Trigger | | | |
# | Pavlov | | | |
# | Tit-for-Two-Tats | | | |
# | Generous Tit-for-Tat | | | |
# | Adaptive | | | |
# | Random (0.7) | | | |
# | Random (0.3) | | | |
# | **Total** | ___ W / ___ L / ___ T | | |
#
# ---
#
# ## Analysis Questions
#
# ### 1. What was your agent's worst loss (greatest point differential) and why?
# (Write 3-5 sentences explaining what happened and why)
#
# ---
#
# ### 2. What pattern do you see in wins vs. losses?
#
# (Which types of opponents does your agent beat/lose to? What do those agent types have in common?)
#
# ---
#
# ### 3. What would make an agent more competitive?
#
# (What specific changes would you make? Why would these help? Think about how to outsmart the agents you're currently losing to)
#
# ---
#
# **Next:** Proceed to Part 3 to implement your improvements!

# %%
class ImprovedEvolvableAgent(Agent):
    """
    IMPROVED agent with better gene encoding
    
    Students can modify:
    - Number of genes (currently 6, could add more)
    - What genes control
    - Decision logic (how genes map to actions)
    """
    
    def __init__(self, genes=None, name="Improved Agent"):
        if genes is None:
            # TODO: Students can change number of genes here
            genes = [random.random() for _ in range(6)]
        
        self.genes = genes
        super().__init__(name, f"Genes: [{', '.join([f'{g:.2f}' for g in genes])}]")
    
    def choose_action(self) -> bool:
        """
        IMPROVED decision logic - AGGRESSIVE VERSION
        More likely to retaliate, less exploitable
        """
        
        # First 3 rounds: use initial cooperation gene
        if self.round_num < 3:
            return random.random() < self.genes[0]
        
        # Calculate memory window
        memory_length = max(1, int(self.genes[4] * 10) + 1)
        recent_history = self.history[-memory_length:]
        cooperation_rate = sum(recent_history) / len(recent_history)
        
        # AGGRESSIVE STRATEGY: Higher threshold for cooperation
        
        # Only cooperate if opponent is VERY cooperative (>80%)
        if cooperation_rate > 0.8:
            return random.random() < self.genes[1]  # gene[1] should evolve HIGH
        
        # If somewhat cooperative (50-80%), be cautious
        elif cooperation_rate > 0.5:
            # Mix of cooperation and defection
            coop_prob = self.genes[1] * (cooperation_rate - 0.5) * 2  # Scale 0-1
            return random.random() < coop_prob
        
        # If aggressive (<50%), retaliate hard
        else:
            # Mostly defect, with small chance to forgive
            if random.random() < self.genes[3] * 0.3:  # Reduced forgiveness
                return INVEST
            else:
                return UNDERCUT
    
    def save_to_file(self, filename):
        """Save agent to JSON"""
        data = {
            'name': self.name,
            'genes': self.genes,
            'description': self.description
        }
        with open(filename, 'w') as f:
            json.dump(data, f, indent=2)
        print(f"✅ Agent saved to {filename}")

# %%
print("\n" + "="*70)
print("🔧 EVOLVING YOUR IMPROVED AGENT!")
print("="*70)

# First, we need to modify the evolve function to use ImprovedEvolvableAgent
# Here's a custom evolution function for the improved agent

def evolve_improved(generations=25, pop_size=20, opponents=None, mutation_rate=0.15, elitism=2):
    """
    Evolve using the ImprovedEvolvableAgent class
    (Same as evolve() but uses ImprovedEvolvableAgent instead of EvolvableAgent)
    """
    if opponents is None:
        opponents = opponent_pool
    
    print(f"\n🧬 EVOLUTION STARTING (Improved Agent)")
    print(f"{'='*70}")
    print(f"Population: {pop_size} | Generations: {generations} | Mutation: {mutation_rate}")
    print(f"Opponents: {len(opponents)} | Elitism: {elitism}")
    print(f"{'='*70}\n")
    
    best_fitness_history = []
    avg_fitness_history = []
    
    # Initialize population with ImprovedEvolvableAgent
    population = [ImprovedEvolvableAgent(name=f"Agent_{i}") for i in range(pop_size)]
    
    best_overall_agent = None
    best_overall_fitness = -float('inf')
    
    for gen in range(generations):
        # Evaluate fitness
        fitnesses = []
        for agent in population:
            fitness = evaluate_fitness(agent, opponents, num_rounds=50)
            fitnesses.append(fitness)
        
        # Track best
        best_fitness = max(fitnesses)
        avg_fitness = sum(fitnesses) / len(fitnesses)
        
        # Update best overall
        best_idx = fitnesses.index(best_fitness)
        if best_fitness > best_overall_fitness:
            best_overall_fitness = best_fitness
            best_overall_agent = ImprovedEvolvableAgent(genes=population[best_idx].genes.copy())
        
        best_fitness_history.append(best_overall_fitness)
        avg_fitness_history.append(avg_fitness)
        
        print(f"Gen {gen+1:3d}/{generations}: "
              f"Best={best_overall_fitness:6.2f} | Avg={avg_fitness:6.2f} | "
              f"Genes={[f'{g:.2f}' for g in population[best_idx].genes]}")
        
        # Create next generation
        if gen < generations - 1:
            sorted_indices = sorted(range(len(fitnesses)), 
                                  key=lambda i: fitnesses[i], 
                                  reverse=True)
            
            # Elitism
            next_population = []
            for i in range(elitism):
                elite_genes = population[sorted_indices[i]].genes.copy()
                next_population.append(ImprovedEvolvableAgent(genes=elite_genes))
            
            # Selection
            selected = tournament_selection(population, fitnesses)
            
            # Crossover and mutation
            while len(next_population) < pop_size:
                parent1, parent2 = random.sample(selected, 2)
                child = crossover_and_mutate(parent1, parent2, mutation_rate)
                # Convert to ImprovedEvolvableAgent
                next_population.append(ImprovedEvolvableAgent(genes=child.genes))
            
            population = next_population
    
    print(f"\n{'='*70}")
    print(f"✅ EVOLUTION COMPLETE!")
    print(f"🏆 Best fitness achieved: {best_overall_fitness:.2f}")
    print(f"{'='*70}\n")
    
    # Plot
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, generations+1), best_fitness_history, 
             label='Best Fitness', linewidth=2, color='green', marker='o')
    plt.plot(range(1, generations+1), avg_fitness_history, 
             label='Average Fitness', linewidth=2, color='blue', marker='s', alpha=0.7)
    plt.xlabel('Generation', fontsize=12)
    plt.ylabel('Fitness (Avg Score per Game)', fontsize=12)
    plt.title('Improved Agent Evolution Progress', fontsize=14, fontweight='bold')
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
    
    return best_overall_agent


# TODO: Experiment with these parameters to find the best improved agent!
my_improved_agent = evolve_improved(
    generations=100,      # Try: 20, 30, 50
    pop_size=30,         # Try: 15, 20, 30
    opponents=opponent_pool,
    mutation_rate=0.1,   # Try: 0.1, 0.15, 0.2
    elitism=2            # Keep top 2 agents each generation
)

print(f"\n🎉 Your improved agent's final genes:")
print(f"   {my_improved_agent.genes}")


# ============================================================================
# Compare: Original vs Improved
# ============================================================================

print("\n" + "="*70)
print("📊 COMPARISON: Original vs Improved Agent")
print("="*70 + "\n")

print("ORIGINAL AGENT:")
wins_orig = 0
for opponent in opponent_pool:
    game = Game(my_evolved_agent, opponent, num_rounds=100)
    my_score, opp_score = game.play()
    if my_score > opp_score:
        wins_orig += 1
        result = "✅ WON"
    elif my_score < opp_score:
        result = "❌ LOST"
    else:
        result = "🤝 TIED"
    print(f"vs {opponent.name:25s}: {my_score:3d} - {opp_score:3d}  {result}")

print(f"\nOriginal Win Rate: {wins_orig / len(opponent_pool) * 100:.1f}%")

print("\n" + "-"*70 + "\n")

print("IMPROVED AGENT:")
wins_improved = 0
for opponent in opponent_pool:
    game = Game(my_improved_agent, opponent, num_rounds=100)
    my_score, opp_score = game.play()
    if my_score > opp_score:
        wins_improved += 1
        result = "✅ WON"
    elif my_score < opp_score:
        result = "❌ LOST"
    else:
        result = "🤝 TIED"
    print(f"vs {opponent.name:25s}: {my_score:3d} - {opp_score:3d}  {result}")

print(f"\nImproved Win Rate: {wins_improved / len(opponent_pool) * 100:.1f}%")

print("\n" + "="*70)
print(f"📈 IMPROVEMENT: +{wins_improved - wins_orig} wins")
print("="*70)


# ============================================================================
# GENERALIZATION TEST: Full Opponent Pool
# ============================================================================

print("\n" + "="*70)
print("🌍 GENERALIZATION TEST: Against ALL Possible Opponents")
print("="*70 + "\n")

print("Testing improved agent against the FULL opponent library:")
print("(including agents it was NOT trained on)\n")

wins_full = 0
losses_full = 0
ties_full = 0

for opponent in full_opponent_pool:
    game = Game(my_improved_agent, opponent, num_rounds=100)
    my_score, opp_score = game.play()
    
    if my_score > opp_score:
        result = "✅ WON"
        wins_full += 1
    elif my_score < opp_score:
        result = "❌ LOST"
        losses_full += 1
    else:
        result = "🤝 TIED"
        ties_full += 1
    
    # Mark if this was a training opponent
    trained_on = "📚" if any(opponent.name == o.name for o in opponent_pool) else "🆕"
    print(f"{trained_on} vs {opponent.name:25s}: {my_score:3d} - {opp_score:3d}  {result}")

print(f"\n📊 Results against ALL {len(full_opponent_pool)} opponents:")
print(f"   Wins: {wins_full} | Losses: {losses_full} | Ties: {ties_full}")
print(f"   Win Rate: {wins_full / len(full_opponent_pool) * 100:.1f}%")
print(f"\n💡 Legend: 📚 = Trained on this opponent | 🆕 = Never seen before")
print("="*70)
# Out:
# ======================================================================
# 🔧 EVOLVING YOUR IMPROVED AGENT!
# ======================================================================
#
# 🧬 EVOLUTION STARTING (Improved Agent)
# ======================================================================
# Population: 30 | Generations: 100 | Mutation: 0.1
# Opponents: 10 | Elitism: 2
# ======================================================================
#
# Gen   1/100: Best=133.50 | Avg=119.88 | Genes=['0.80', '0.41', '0.79', '0.51', '0.96', '0.13']
# Gen   2/100: Best=140.50 | Avg=122.68 | Genes=['0.98', '1.00', '0.89', '0.48', '0.40', '0.46']
# Gen   3/100: Best=141.70 | Avg=126.40 | Genes=['0.98', '1.00', '0.89', '0.48', '0.40', '0.46']
# Gen   4/100: Best=141.70 | Avg=131.00 | Genes=['0.98', '1.00', '0.89', '0.56', '0.40', '0.46']
# Gen   5/100: Best=143.00 | Avg=137.68 | Genes=['0.98', '1.00', '1.00', '0.00', '0.40', '0.46']
# Gen   6/100: Best=143.00 | Avg=137.83 | Genes=['0.98', '1.00', '1.00', '0.00', '0.40', '0.46']
# Gen   7/100: Best=143.10 | Avg=139.00 | Genes=['1.00', '1.00', '1.00', '0.00', '0.40', '0.62']
# Gen   8/100: Best=143.10 | Avg=140.14 | Genes=['0.98', '1.00', '1.00', '0.00', '0.40', '1.00']
# Gen   9/100: Best=143.50 | Avg=138.80 | Genes=['1.00', '1.00', '1.00', '0.00', '0.97', '0.62']
# Gen  10/100: Best=143.50 | Avg=141.11 | Genes=['1.00', '1.00', '1.00', '0.00', '0.40', '1.00']
# Gen  11/100: Best=143.90 | Avg=140.41 | Genes=['0.98', '1.00', '1.00', '0.00', '0.34', '0.47']
# Gen  12/100: Best=143.90 | Avg=140.06 | Genes=['0.89', '1.00', '1.00', '0.00', '0.40', '0.93']
# Gen  13/100: Best=145.60 | Avg=141.31 | Genes=['0.89', '1.00', '1.00', '0.00', '0.34', '0.06']
# Gen  14/100: Best=145.60 | Avg=139.73 | Genes=['1.00', '1.00', '0.93', '0.00', '0.34', '0.06']
# Gen  15/100: Best=145.60 | Avg=139.73 | Genes=['1.00', '1.00', '0.93', '0.00', '0.40', '0.74']
# Gen  16/100: Best=145.60 | Avg=140.59 | Genes=['1.00', '1.00', '0.93', '0.00', '0.32', '0.93']
# Gen  17/100: Best=145.60 | Avg=140.83 | Genes=['1.00', '1.00', '1.00', '0.01', '0.40', '0.74']
# Gen  18/100: Best=145.60 | Avg=140.88 | Genes=['1.00', '1.00', '1.00', '0.01', '0.40', '0.74']
# Gen  19/100: Best=145.60 | Avg=141.03 | Genes=['1.00', '1.00', '1.00', '0.00', '0.34', '1.00']
# Gen  20/100: Best=145.60 | Avg=141.68 | Genes=['1.00', '1.00', '0.93', '0.01', '0.40', '0.97']
# Gen  21/100: Best=145.60 | Avg=140.48 | Genes=['1.00', '1.00', '0.83', '0.00', '0.32', '0.97']
# Gen  22/100: Best=145.60 | Avg=141.18 | Genes=['1.00', '1.00', '0.93', '0.00', '0.32', '0.97']
# Gen  23/100: Best=145.60 | Avg=140.73 | Genes=['1.00', '1.00', '0.73', '0.00', '0.34', '1.00']
# Gen  24/100: Best=145.60 | Avg=140.34 | Genes=['0.98', '1.00', '1.00', '0.00', '0.40', '1.00']
# Gen  25/100: Best=145.60 | Avg=140.79 | Genes=['1.00', '1.00', '1.00', '0.00', '0.34', '1.00']
# Gen  26/100: Best=145.60 | Avg=141.09 | Genes=['1.00', '1.00', '1.00', '0.00', '0.34', '1.00']
# Gen  27/100: Best=145.60 | Avg=140.13 | Genes=['1.00', '1.00', '1.00', '0.00', '0.18', '1.00']
# Gen  28/100: Best=145.60 | Avg=139.31 | Genes=['1.00', '1.00', '1.00', '0.00', '0.34', '1.00']
# Gen  29/100: Best=145.60 | Avg=139.67 | Genes=['1.00', '1.00', '1.00', '0.00', '0.34', '1.00']
# Gen  30/100: Best=145.60 | Avg=140.58 | Genes=['1.00', '1.00', '0.77', '0.00', '0.34', '1.00']
# Gen  31/100: Best=145.60 | Avg=140.24 | Genes=['1.00', '1.00', '0.77', '0.08', '0.49', '1.00']
# Gen  32/100: Best=145.60 | Avg=140.94 | Genes=['1.00', '1.00', '1.00', '0.11', '0.32', '1.00']
# Gen  33/100: Best=145.60 | Avg=140.20 | Genes=['1.00', '1.00', '1.00', '0.00', '0.34', '1.00']
# Gen  34/100: Best=145.60 | Avg=139.90 | Genes=['1.00', '1.00', '1.00', '0.00', '0.37', '1.00']
# Gen  35/100: Best=145.60 | Avg=139.66 | Genes=['1.00', '1.00', '0.77', '0.00', '0.37', '0.99']
# Gen  36/100: Best=145.60 | Avg=140.89 | Genes=['1.00', '1.00', '1.00', '0.00', '0.34', '1.00']
# Gen  37/100: Best=145.60 | Avg=137.70 | Genes=['1.00', '1.00', '1.00', '0.00', '0.37', '0.99']
# Gen  38/100: Best=145.60 | Avg=140.45 | Genes=['1.00', '1.00', '1.00', '0.11', '0.37', '0.99']
# Gen  39/100: Best=145.60 | Avg=140.82 | Genes=['1.00', '1.00', '0.78', '0.08', '0.34', '0.87']
# Gen  40/100: Best=145.60 | Avg=140.46 | Genes=['1.00', '1.00', '0.78', '0.08', '0.34', '0.87']
# Gen  41/100: Best=145.60 | Avg=140.47 | Genes=['1.00', '1.00', '0.55', '0.00', '0.37', '1.00']
# Gen  42/100: Best=145.60 | Avg=141.52 | Genes=['1.00', '1.00', '0.55', '0.00', '0.37', '0.94']
# Gen  43/100: Best=146.10 | Avg=141.15 | Genes=['0.84', '1.00', '0.55', '0.00', '0.37', '0.94']
# Gen  44/100: Best=146.10 | Avg=141.74 | Genes=['1.00', '1.00', '0.60', '0.00', '0.37', '0.94']
# Gen  45/100: Best=146.10 | Avg=140.96 | Genes=['1.00', '1.00', '0.60', '0.00', '0.37', '0.94']
# Gen  46/100: Best=146.10 | Avg=139.99 | Genes=['1.00', '1.00', '0.60', '0.00', '0.37', '0.94']
# Gen  47/100: Best=146.10 | Avg=140.63 | Genes=['1.00', '1.00', '0.60', '0.00', '0.35', '0.94']
# Gen  48/100: Best=146.10 | Avg=140.92 | Genes=['1.00', '1.00', '0.48', '0.00', '0.35', '0.94']
# Gen  49/100: Best=146.10 | Avg=140.89 | Genes=['1.00', '1.00', '0.60', '0.00', '0.35', '0.94']
# Gen  50/100: Best=146.10 | Avg=141.62 | Genes=['1.00', '1.00', '0.48', '0.00', '0.35', '1.00']
# Gen  51/100: Best=147.50 | Avg=140.69 | Genes=['1.00', '1.00', '0.48', '0.00', '0.35', '0.94']
# Gen  52/100: Best=147.50 | Avg=141.19 | Genes=['1.00', '1.00', '0.48', '0.00', '0.31', '0.94']
# Gen  53/100: Best=147.50 | Avg=140.93 | Genes=['1.00', '1.00', '0.48', '0.00', '0.35', '0.94']
# Gen  54/100: Best=147.50 | Avg=141.49 | Genes=['1.00', '1.00', '0.48', '0.00', '0.35', '0.94']
# Gen  55/100: Best=147.50 | Avg=141.72 | Genes=['1.00', '1.00', '0.29', '0.00', '0.35', '0.94']
# Gen  56/100: Best=147.50 | Avg=141.75 | Genes=['1.00', '1.00', '0.51', '0.06', '0.37', '0.94']
# Gen  57/100: Best=147.50 | Avg=140.64 | Genes=['1.00', '1.00', '0.44', '0.00', '0.21', '1.00']
# Gen  58/100: Best=147.50 | Avg=140.60 | Genes=['0.99', '1.00', '0.14', '0.00', '0.35', '1.00']
# Gen  59/100: Best=147.50 | Avg=141.32 | Genes=['0.92', '1.00', '0.20', '0.00', '0.35', '0.94']
# Gen  60/100: Best=147.50 | Avg=140.18 | Genes=['1.00', '1.00', '0.51', '0.00', '0.35', '1.00']
# Gen  61/100: Best=147.50 | Avg=140.56 | Genes=['1.00', '1.00', '0.51', '0.00', '0.35', '1.00']
# Gen  62/100: Best=147.50 | Avg=139.91 | Genes=['0.99', '1.00', '0.20', '0.00', '0.35', '1.00']
# Gen  63/100: Best=147.50 | Avg=141.66 | Genes=['0.99', '1.00', '0.29', '0.00', '0.40', '0.94']
# Gen  64/100: Best=147.50 | Avg=140.58 | Genes=['0.99', '1.00', '0.29', '0.00', '0.40', '0.94']
# Gen  65/100: Best=147.50 | Avg=139.92 | Genes=['1.00', '1.00', '0.20', '0.00', '0.40', '0.94']
# Gen  66/100: Best=147.50 | Avg=140.22 | Genes=['0.99', '1.00', '0.20', '0.00', '0.40', '0.94']
# Gen  67/100: Best=147.50 | Avg=138.78 | Genes=['1.00', '1.00', '0.20', '0.00', '0.40', '0.96']
# Gen  68/100: Best=147.50 | Avg=140.38 | Genes=['0.99', '1.00', '0.20', '0.00', '0.48', '0.94']
# Gen  69/100: Best=147.50 | Avg=141.60 | Genes=['1.00', '1.00', '0.20', '0.00', '0.48', '0.94']
# Gen  70/100: Best=147.50 | Avg=141.05 | Genes=['1.00', '1.00', '0.20', '0.00', '0.48', '0.94']
# Gen  71/100: Best=147.50 | Avg=140.25 | Genes=['1.00', '1.00', '0.20', '0.00', '0.48', '0.94']
# Gen  72/100: Best=147.50 | Avg=140.95 | Genes=['1.00', '1.00', '0.20', '0.00', '0.48', '0.86']
# Gen  73/100: Best=147.50 | Avg=141.84 | Genes=['1.00', '1.00', '0.20', '0.00', '0.12', '0.94']
# Gen  74/100: Best=147.50 | Avg=141.22 | Genes=['1.00', '1.00', '0.05', '0.00', '0.48', '0.94']
# Gen  75/100: Best=147.50 | Avg=140.62 | Genes=['1.00', '1.00', '0.05', '0.00', '0.48', '0.94']
# Gen  76/100: Best=147.50 | Avg=141.14 | Genes=['0.99', '1.00', '0.04', '0.00', '0.48', '0.95']
# Gen  77/100: Best=147.50 | Avg=139.34 | Genes=['1.00', '1.00', '0.05', '0.00', '0.48', '0.94']
# Gen  78/100: Best=147.50 | Avg=140.17 | Genes=['1.00', '1.00', '0.20', '0.00', '0.48', '0.56']
# Gen  79/100: Best=147.50 | Avg=141.02 | Genes=['1.00', '1.00', '0.05', '0.00', '0.48', '0.94']
# Gen  80/100: Best=147.50 | Avg=140.33 | Genes=['1.00', '1.00', '0.04', '0.00', '0.48', '0.94']
# Gen  81/100: Best=147.50 | Avg=141.80 | Genes=['1.00', '1.00', '0.05', '0.00', '0.48', '0.85']
# Gen  82/100: Best=147.50 | Avg=140.35 | Genes=['1.00', '1.00', '0.04', '0.26', '0.48', '0.57']
# Gen  83/100: Best=147.50 | Avg=139.79 | Genes=['1.00', '1.00', '0.20', '0.00', '0.48', '0.94']
# Gen  84/100: Best=147.50 | Avg=140.30 | Genes=['1.00', '1.00', '0.16', '0.00', '0.48', '0.93']
# Gen  85/100: Best=147.50 | Avg=140.92 | Genes=['1.00', '1.00', '0.04', '0.00', '0.48', '0.94']
# Gen  86/100: Best=147.50 | Avg=141.74 | Genes=['1.00', '1.00', '0.14', '0.00', '0.48', '0.82']
# Gen  87/100: Best=147.50 | Avg=140.37 | Genes=['0.99', '1.00', '0.05', '0.25', '0.48', '1.00']
# Gen  88/100: Best=147.50 | Avg=140.62 | Genes=['1.00', '1.00', '0.04', '0.00', '0.48', '0.93']
# Gen  89/100: Best=147.50 | Avg=140.94 | Genes=['1.00', '1.00', '0.14', '0.00', '0.46', '0.93']
# Gen  90/100: Best=147.50 | Avg=141.55 | Genes=['1.00', '1.00', '0.04', '0.00', '0.46', '1.00']
# Gen  91/100: Best=147.50 | Avg=140.03 | Genes=['1.00', '1.00', '0.04', '0.00', '0.48', '0.93']
# Gen  92/100: Best=147.50 | Avg=140.88 | Genes=['1.00', '1.00', '0.05', '0.00', '0.30', '1.00']
# Gen  93/100: Best=147.50 | Avg=139.72 | Genes=['1.00', '1.00', '0.04', '0.00', '0.48', '0.93']
# Gen  94/100: Best=147.50 | Avg=140.73 | Genes=['1.00', '1.00', '0.07', '0.00', '0.48', '0.95']
# Gen  95/100: Best=147.50 | Avg=140.30 | Genes=['1.00', '1.00', '0.29', '0.00', '0.48', '1.00']
# Gen  96/100: Best=147.50 | Avg=141.29 | Genes=['0.98', '1.00', '0.07', '0.00', '0.48', '0.75']
# Gen  97/100: Best=147.50 | Avg=140.95 | Genes=['0.98', '1.00', '0.29', '0.00', '0.48', '1.00']
# Gen  98/100: Best=147.50 | Avg=140.94 | Genes=['1.00', '1.00', '0.49', '0.26', '0.48', '0.66']
# Gen  99/100: Best=147.50 | Avg=141.19 | Genes=['1.00', '1.00', '0.29', '0.00', '0.48', '0.90']
# Gen 100/100: Best=147.50 | Avg=139.93 | Genes=['0.98', '1.00', '0.29', '0.00', '0.48', '0.56']
#
# ======================================================================
# ✅ EVOLUTION COMPLETE!
# 🏆 Best fitness achieved: 147.50
# ======================================================================
# 🎉 Your improved agent's final genes:
#    [1.0, 1.0, 0.48133874186118913, 0.0, 0.3454967235855081, 0.9359113580017795]
#
# ======================================================================
# 📊 COMPARISON: Original vs Improved Agent
# ======================================================================
#
# ORIGINAL AGENT:
# vs Random (0.9)             : 294 - 289  ✅ WON
# vs Random (0.1)             : 145 - 100  ✅ WON
# vs Hard Majority            : 324 - 264  ✅ WON
# vs Adaptive                 : 306 - 291  ✅ WON
# vs Random (0.7)             : 236 - 291  ❌ LOST
# vs Grim Trigger             : 112 - 127  ❌ LOST
# vs Pavlov                   : 242 - 192  ✅ WON
# vs Tit-for-Tat              : 293 - 288  ✅ WON
# vs Tit-for-Two-Tats         : 313 - 273  ✅ WON
# vs Always Invest            : 318 - 273  ✅ WON
#
# Original Win Rate: 80.0%
#
# ----------------------------------------------------------------------
#
# IMPROVED AGENT:
# vs Random (0.9)             : 311 - 251  ✅ WON
# vs Random (0.1)             : 149 -  99  ✅ WON
# vs Hard Majority            : 300 - 300  🤝 TIED
# vs Adaptive                 : 300 - 300  🤝 TIED
# vs Random (0.7)             : 308 - 173  ✅ WON
# vs Grim Trigger             : 300 - 300  🤝 TIED
# vs Pavlov                   : 300 - 300  🤝 TIED
# vs Tit-for-Tat              : 300 - 300  🤝 TIED
# vs Tit-for-Two-Tats         : 300 - 300  🤝 TIED
# vs Always Invest            : 300 - 300  🤝 TIED
#
# Improved Win Rate: 30.0%
#
# ======================================================================
# 📈 IMPROVEMENT: +-5 wins
# ======================================================================
#
# ======================================================================
# 🌍 GENERALIZATION TEST: Against ALL Possible Opponents
# ======================================================================
#
# Testing improved agent against the FULL opponent library:
# (including agents it was NOT trained on)
#
# 📚 vs Always Invest            : 300 - 300  🤝 TIED
# 📚 vs Tit-for-Tat              : 300 - 300  🤝 TIED
# 📚 vs Grim Trigger             : 300 - 300  🤝 TIED
# 📚 vs Pavlov                   : 300 - 300  🤝 TIED
# 📚 vs Tit-for-Two-Tats         : 300 - 300  🤝 TIED
# 🆕 vs Generous Tit-for-Tat     : 300 - 300  🤝 TIED
# 📚 vs Adaptive                 : 300 - 300  🤝 TIED
# 🆕 vs Always Undercut          :  97 - 112  ❌ LOST
# 🆕 vs Suspicious Tit-for-Tat   : 113 - 113  🤝 TIED
# 🆕 vs Gradual                  : 300 - 300  🤝 TIED
# 🆕 vs Prober                   : 102 - 112  ❌ LOST
# 📚 vs Hard Majority            : 300 - 300  🤝 TIED
# 🆕 vs Soft Majority            : 300 - 300  🤝 TIED
# 📚 vs Random (0.9)             : 304 - 279  ✅ WON
# 📚 vs Random (0.7)             : 307 - 187  ✅ WON
# 🆕 vs Random (0.5)             : 270 - 105  ✅ WON
# 🆕 vs Random (0.3)             : 197 -  87  ✅ WON
# 📚 vs Random (0.1)             : 129 - 104  ✅ WON
#
# 📊 Results against ALL 18 opponents:
#    Wins: 5 | Losses: 2 | Ties: 11
#    Win Rate: 27.8%
#
# 💡 Legend: 📚 = Trained on this opponent | 🆕 = Never seen before
# ======================================================================

# %%
print("\n" + "="*70)
print("🏆 FULL TOURNAMENT COMPARISON")
print("="*70 + "\n")

# Create tournament with original agent
print("Running tournament with ORIGINAL agent...")
original_tournament_agents = full_opponent_pool + [my_evolved_agent]
original_tournament = Tournament(original_tournament_agents, rounds_per_match=100, num_tournaments=1)
original_tournament.run_tournament()

# Create tournament with improved agent
print("\n" + "-"*70)
print("\nRunning tournament with IMPROVED agent...")
improved_tournament_agents = full_opponent_pool + [my_improved_agent]
improved_tournament = Tournament(improved_tournament_agents, rounds_per_match=100, num_tournaments=1)
improved_tournament.run_tournament()

# Compare rankings
print("\n" + "="*70)
print("📊 TOURNAMENT RESULTS COMPARISON")
print("="*70 + "\n")

original_rankings = original_tournament.get_rankings()
improved_rankings = improved_tournament.get_rankings()

# Find where each agent placed
original_rank = None
improved_rank = None
original_score = None
improved_score = None

for rank, (name, score) in enumerate(original_rankings, 1):
    if name == my_evolved_agent.name:
        original_rank = rank
        original_score = score

for rank, (name, score) in enumerate(improved_rankings, 1):
    if name == my_improved_agent.name:
        improved_rank = rank
        improved_score = score

print(f"ORIGINAL AGENT:")
print(f"  Rank: {original_rank} / {len(original_rankings)}")
print(f"  Total Score: {original_score:,}")
print()
print(f"IMPROVED AGENT:")
print(f"  Rank: {improved_rank} / {len(improved_rankings)}")
print(f"  Total Score: {improved_score:,}")
print()
print(f"IMPROVEMENT:")
print(f"  Rank Change: {original_rank - improved_rank} positions {'⬆️' if improved_rank < original_rank else '⬇️' if improved_rank > original_rank else '➡️'}")
print(f"  Score Change: +{improved_score - original_score:,} points ({(improved_score - original_score)/original_score*100:.1f}%)")
print("="*70)

# Show full leaderboard
print("\n🏆 IMPROVED AGENT TOURNAMENT LEADERBOARD:")
print("=" * 50)
for rank, (name, score) in enumerate(improved_rankings, 1):
    emoji = "🥇" if rank == 1 else "🥈" if rank == 2 else "🥉" if rank == 3 else "  "
    marker = " ⭐ YOUR AGENT" if name == my_improved_agent.name else ""
    print(f"{emoji} {rank:2d}. {name:25s}: {score:,} points{marker}")
# Out:
# ======================================================================
# 🏆 FULL TOURNAMENT COMPARISON
# ======================================================================
#
# Running tournament with ORIGINAL agent...
# Running 1 tournament(s) with 19 agents...
# Match 1/342: Always Invest vs Tit-for-Tat
# Match 2/342: Always Invest vs Grim Trigger
# Match 3/342: Always Invest vs Pavlov
# Match 4/342: Always Invest vs Tit-for-Two-Tats
# Match 5/342: Always Invest vs Generous Tit-for-Tat
# Match 6/342: Always Invest vs Adaptive
# Match 7/342: Always Invest vs Always Undercut
# Match 8/342: Always Invest vs Suspicious Tit-for-Tat
# Match 9/342: Always Invest vs Gradual
# Match 10/342: Always Invest vs Prober
# Match 11/342: Always Invest vs Hard Majority
# Match 12/342: Always Invest vs Soft Majority
# Match 13/342: Always Invest vs Random (0.9)
# Match 14/342: Always Invest vs Random (0.7)
# Match 15/342: Always Invest vs Random (0.5)
# Match 16/342: Always Invest vs Random (0.3)
# Match 17/342: Always Invest vs Random (0.1)
# Match 18/342: Always Invest vs Evolved Agent
# Match 19/342: Tit-for-Tat vs Always Invest
# Match 20/342: Tit-for-Tat vs Grim Trigger
# Match 21/342: Tit-for-Tat vs Pavlov
# Match 22/342: Tit-for-Tat vs Tit-for-Two-Tats
# Match 23/342: Tit-for-Tat vs Generous Tit-for-Tat
# Match 24/342: Tit-for-Tat vs Adaptive
# Match 25/342: Tit-for-Tat vs Always Undercut
# Match 26/342: Tit-for-Tat vs Suspicious Tit-for-Tat
# Match 27/342: Tit-for-Tat vs Gradual
# Match 206/342: Hard Majority vs Always Undercut
# Match 207/342: Hard Majority vs Suspicious Tit-for-Tat
# Match 208/342: Hard Majority vs Gradual
# Match 209/342: Hard Majority vs Prober
# Match 210/342: Hard Majority vs Soft Majority
# Match 211/342: Hard Majority vs Random (0.9)
# Match 212/342: Hard Majority vs Random (0.7)
# Match 213/342: Hard Majority vs Random (0.5)
# Match 214/342: Hard Majority vs Random (0.3)
# Match 215/342: Hard Majority vs Random (0.1)
# Match 216/342: Hard Majority vs Evolved Agent
# Match 217/342: Soft Majority vs Always Invest
# Match 218/342: Soft Majority vs Tit-for-Tat
# Match 219/342: Soft Majority vs Grim Trigger
# Match 220/342: Soft Majority vs Pavlov
# Match 221/342: Soft Majority vs Tit-for-Two-Tats
# Match 222/342: Soft Majority vs Generous Tit-for-Tat
# Match 223/342: Soft Majority vs Adaptive
# Match 224/342: Soft Majority vs Always Undercut
# Match 225/342: Soft Majority vs Suspicious Tit-for-Tat
# Match 226/342: Soft Majority vs Gradual
# Match 227/342: Soft Majority vs Prober
# Match 228/342: Soft Majority vs Hard Majority
# Match 229/342: Soft Majority vs Random (0.9)
# Match 230/342: Soft Majority vs Random (0.7)
# Match 231/342: Soft Majority vs Random (0.5)
# Match 232/342: Soft Majority vs Random (0.3)
# Match 233/342: Soft Majority vs Random (0.1)
# Match 234/342: Soft Majority vs Evolved Agent
# Match 235/342: Random (0.9) vs Always Invest
# Match 236/342: Random (0.9) vs Tit-for-Tat
# Match 237/342: Random (0.9) vs Grim Trigger
# Match 238/342: Random (0.9) vs Pavlov
# Match 239/342: Random (0.9) vs Tit-for-Two-Tats
# Match 240/342: Random (0.9) vs Generous Tit-for-Tat
# Match 241/342: Random (0.9) vs Adaptive
# Match 242/342: Random (0.9) vs Always Undercut
# Match 243/342: Random (0.9) vs Suspicious Tit-for-Tat
# Match 244/342: Random (0.9) vs Gradual
# Match 245/342: Random (0.9) vs Prober
# Match 246/342: Random (0.9) vs Hard Majority
# Match 247/342: Random (0.9) vs Soft Majority
# Match 248/342: Random (0.9) vs Random (0.7)
# Match 249/342: Random (0.9) vs Random (0.5)
# Match 250/342: Random (0.9) vs Random (0.3)
# Match 251/342: Random (0.9) vs Random (0.1)
# Match 252/342: Random (0.9) vs Evolved Agent
# Match 253/342: Random (0.7) vs Always Invest
# Match 254/342: Random (0.7) vs Tit-for-Tat
# Match 255/342: Random (0.7) vs Grim Trigger
# Match 256/342: Random (0.7) vs Pavlov
# Match 257/342: Random (0.7) vs Tit-for-Two-Tats
# Match 258/342: Random (0.7) vs Generous Tit-for-Tat
# Match 259/342: Random (0.7) vs Adaptive
# Match 260/342: Random (0.7) vs Always Undercut
# Match 261/342: Random (0.7) vs Suspicious Tit-for-Tat
# Match 262/342: Random (0.7) vs Gradual
# Match 263/342: Random (0.7) vs Prober
# Match 264/342: Random (0.7) vs Hard Majority
# Match 265/342: Random (0.7) vs Soft Majority
# Match 266/342: Random (0.7) vs Random (0.9)
# Match 267/342: Random (0.7) vs Random (0.5)
# Match 268/342: Random (0.7) vs Random (0.3)
# Match 269/342: Random (0.7) vs Random (0.1)
# Match 270/342: Random (0.7) vs Evolved Agent
# Match 271/342: Random (0.5) vs Always Invest
# Match 272/342: Random (0.5) vs Tit-for-Tat
# Match 273/342: Random (0.5) vs Grim Trigger
# Match 274/342: Random (0.5) vs Pavlov
# Match 275/342: Random (0.5) vs Tit-for-Two-Tats
# Match 276/342: Random (0.5) vs Generous Tit-for-Tat
# Match 277/342: Random (0.5) vs Adaptive
# Match 278/342: Random (0.5) vs Always Undercut
# Match 279/342: Random (0.5) vs Suspicious Tit-for-Tat
# Match 280/342: Random (0.5) vs Gradual
# Match 281/342: Random (0.5) vs Prober
# Match 282/342: Random (0.5) vs Hard Majority
# Match 283/342: Random (0.5) vs Soft Majority
# Match 284/342: Random (0.5) vs Random (0.9)
# Match 285/342: Random (0.5) vs Random (0.7)
# Match 286/342: Random (0.5) vs Random (0.3)
# Match 287/342: Random (0.5) vs Random (0.1)
# Match 288/342: Random (0.5) vs Evolved Agent
# Match 289/342: Random (0.3) vs Always Invest
# Match 290/342: Random (0.3) vs Tit-for-Tat
# Match 291/342: Random (0.3) vs Grim Trigger
# Match 292/342: Random (0.3) vs Pavlov
# Match 293/342: Random (0.3) vs Tit-for-Two-Tats
# Match 294/342: Random (0.3) vs Generous Tit-for-Tat
# Match 295/342: Random (0.3) vs Adaptive
# Match 296/342: Random (0.3) vs Always Undercut
# Match 297/342: Random (0.3) vs Suspicious Tit-for-Tat
# Match 298/342: Random (0.3) vs Gradual
# Match 299/342: Random (0.3) vs Prober
# Match 300/342: Random (0.3) vs Hard Majority
# Match 301/342: Random (0.3) vs Soft Majority
# Match 302/342: Random (0.3) vs Random (0.9)
# Match 303/342: Random (0.3) vs Random (0.7)
# Match 304/342: Random (0.3) vs Random (0.5)
# Match 305/342: Random (0.3) vs Random (0.1)
# Match 306/342: Random (0.3) vs Evolved Agent
# Match 307/342: Random (0.1) vs Always Invest
# Match 308/342: Random (0.1) vs Tit-for-Tat
# Match 309/342: Random (0.1) vs Grim Trigger
# Match 310/342: Random (0.1) vs Pavlov
# Match 311/342: Random (0.1) vs Tit-for-Two-Tats
# Match 312/342: Random (0.1) vs Generous Tit-for-Tat
# Match 313/342: Random (0.1) vs Adaptive
# Match 314/342: Random (0.1) vs Always Undercut
# Match 315/342: Random (0.1) vs Suspicious Tit-for-Tat
# Match 316/342: Random (0.1) vs Gradual
# Match 317/342: Random (0.1) vs Prober
# Match 318/342: Random (0.1) vs Hard Majority
# Match 319/342: Random (0.1) vs Soft Majority
# Match 320/342: Random (0.1) vs Random (0.9)
# Match 321/342: Random (0.1) vs Random (0.7)
# Match 322/342: Random (0.1) vs Random (0.5)
# Match 323/342: Random (0.1) vs Random (0.3)
# Match 324/342: Random (0.1) vs Evolved Agent
# Match 325/342: Evolved Agent vs Always Invest
# Match 326/342: Evolved Agent vs Tit-for-Tat
# Match 327/342: Evolved Agent vs Grim Trigger
# Match 328/342: Evolved Agent vs Pavlov
# Match 159/342: Suspicious Tit-for-Tat vs Random (0.5)
# Match 160/342: Suspicious Tit-for-Tat vs Random (0.3)
# Match 161/342: Suspicious Tit-for-Tat vs Random (0.1)
# Match 162/342: Suspicious Tit-for-Tat vs Improved Agent
# Match 163/342: Gradual vs Always Invest
# Match 164/342: Gradual vs Tit-for-Tat
# Match 165/342: Gradual vs Grim Trigger
# Match 166/342: Gradual vs Pavlov
# Match 167/342: Gradual vs Tit-for-Two-Tats
# Match 168/342: Gradual vs Generous Tit-for-Tat
# Match 169/342: Gradual vs Adaptive
# Match 170/342: Gradual vs Always Undercut
# Match 171/342: Gradual vs Suspicious Tit-for-Tat
# Match 172/342: Gradual vs Prober
# Match 173/342: Gradual vs Hard Majority
# Match 174/342: Gradual vs Soft Majority
# Match 175/342: Gradual vs Random (0.9)
# Match 176/342: Gradual vs Random (0.7)
# Match 177/342: Gradual vs Random (0.5)
# Match 178/342: Gradual vs Random (0.3)
# Match 179/342: Gradual vs Random (0.1)
# Match 180/342: Gradual vs Improved Agent
# Match 181/342: Prober vs Always Invest
# Match 182/342: Prober vs Tit-for-Tat
# Match 183/342: Prober vs Grim Trigger
# Match 184/342: Prober vs Pavlov
# Match 185/342: Prober vs Tit-for-Two-Tats
# Match 186/342: Prober vs Generous Tit-for-Tat
# Match 187/342: Prober vs Adaptive
# Match 188/342: Prober vs Always Undercut
# Match 189/342: Prober vs Suspicious Tit-for-Tat
# Match 190/342: Prober vs Gradual
# Match 191/342: Prober vs Hard Majority
# Match 192/342: Prober vs Soft Majority
# Match 193/342: Prober vs Random (0.9)
# Match 194/342: Prober vs Random (0.7)
# Match 195/342: Prober vs Random (0.5)
# Match 196/342: Prober vs Random (0.3)
# Match 197/342: Prober vs Random (0.1)
# Match 198/342: Prober vs Improved Agent
# Match 199/342: Hard Majority vs Always Invest
# Match 200/342: Hard Majority vs Tit-for-Tat
# Match 201/342: Hard Majority vs Grim Trigger
# Match 202/342: Hard Majority vs Pavlov
# Match 203/342: Hard Majority vs Tit-for-Two-Tats
# Match 204/342: Hard Majority vs Generous Tit-for-Tat
# Match 205/342: Hard Majority vs Adaptive
# Match 206/342: Hard Majority vs Always Undercut
# Match 207/342: Hard Majority vs Suspicious Tit-for-Tat
# Match 208/342: Hard Majority vs Gradual
# Match 209/342: Hard Majority vs Prober
# Match 210/342: Hard Majority vs Soft Majority
# Match 211/342: Hard Majority vs Random (0.9)
# Match 212/342: Hard Majority vs Random (0.7)
# Match 213/342: Hard Majority vs Random (0.5)
# Match 214/342: Hard Majority vs Random (0.3)
# Match 215/342: Hard Majority vs Random (0.1)
# Match 216/342: Hard Majority vs Improved Agent
# Match 217/342: Soft Majority vs Always Invest
# Match 218/342: Soft Majority vs Tit-for-Tat
# Match 219/342: Soft Majority vs Grim Trigger
# Match 220/342: Soft Majority vs Pavlov
# Match 221/342: Soft Majority vs Tit-for-Two-Tats
# Match 222/342: Soft Majority vs Generous Tit-for-Tat
# Match 223/342: Soft Majority vs Adaptive
# Match 224/342: Soft Majority vs Always Undercut
# Match 225/342: Soft Majority vs Suspicious Tit-for-Tat
# Match 226/342: Soft Majority vs Gradual
# Match 227/342: Soft Majority vs Prober
# Match 228/342: Soft Majority vs Hard Majority
# Match 229/342: Soft Majority vs Random (0.9)
# Match 230/342: Soft Majority vs Random (0.7)
# Match 231/342: Soft Majority vs Random (0.5)
# Match 232/342: Soft Majority vs Random (0.3)
# Match 233/342: Soft Majority vs Random (0.1)
# Match 234/342: Soft Majority vs Improved Agent
# Match 235/342: Random (0.9) vs Always Invest
# Match 236/342: Random (0.9) vs Tit-for-Tat
# Match 237/342: Random (0.9) vs Grim Trigger
# Match 238/342: Random (0.9) vs Pavlov
# Match 239/342: Random (0.9) vs Tit-for-Two-Tats
# Match 240/342: Random (0.9) vs Generous Tit-for-Tat
# Match 241/342: Random (0.9) vs Adaptive
# Match 242/342: Random (0.9) vs Always Undercut
# Match 243/342: Random (0.9) vs Suspicious Tit-for-Tat
# Match 244/342: Random (0.9) vs Gradual
# Match 245/342: Random (0.9) vs Prober
# Match 246/342: Random (0.9) vs Hard Majority
# Match 247/342: Random (0.9) vs Soft Majority
# Match 248/342: Random (0.9) vs Random (0.7)
# Match 249/342: Random (0.9) vs Random (0.5)
# Match 250/342: Random (0.9) vs Random (0.3)
# Match 251/342: Random (0.9) vs Random (0.1)
# Match 252/342: Random (0.9) vs Improved Agent
# Match 253/342: Random (0.7) vs Always Invest
# Match 254/342: Random (0.7) vs Tit-for-Tat
# Match 255/342: Random (0.7) vs Grim Trigger
# Match 256/342: Random (0.7) vs Pavlov
# Match 257/342: Random (0.7) vs Tit-for-Two-Tats
# Match 258/342: Random (0.7) vs Generous Tit-for-Tat
# Match 259/342: Random (0.7) vs Adaptive
# Match 260/342: Random (0.7) vs Always Undercut
# Match 261/342: Random (0.7) vs Suspicious Tit-for-Tat
# Match 262/342: Random (0.7) vs Gradual
# Match 263/342: Random (0.7) vs Prober
# Match 264/342: Random (0.7) vs Hard Majority
# Match 265/342: Random (0.7) vs Soft Majority
# Match 266/342: Random (0.7) vs Random (0.9)
# Match 267/342: Random (0.7) vs Random (0.5)
# Match 268/342: Random (0.7) vs Random (0.3)
# Match 269/342: Random (0.7) vs Random (0.1)
# Match 270/342: Random (0.7) vs Improved Agent
# Match 271/342: Random (0.5) vs Always Invest
# Match 272/342: Random (0.5) vs Tit-for-Tat
# Match 273/342: Random (0.5) vs Grim Trigger
# Match 274/342: Random (0.5) vs Pavlov
# Match 275/342: Random (0.5) vs Tit-for-Two-Tats
# Match 276/342: Random (0.5) vs Generous Tit-for-Tat
# Match 277/342: Random (0.5) vs Adaptive
# Match 278/342: Random (0.5) vs Always Undercut
# Match 279/342: Random (0.5) vs Suspicious Tit-for-Tat
# Match 280/342: Random (0.5) vs Gradual
# Match 281/342: Random (0.5) vs Prober
# Match 282/342: Random (0.5) vs Hard Majority
# Match 283/342: Random (0.5) vs Soft Majority
# Match 284/342: Random (0.5) vs Random (0.9)
# Match 285/342: Random (0.5) vs Random (0.7)
# Match 286/342: Random (0.5) vs Random (0.3)
# Match 287/342: Random (0.5) vs Random (0.1)
# Match 288/342: Random (0.5) vs Improved Agent
# Match 289/342: Random (0.3) vs Always Invest
# Match 290/342: Random (0.3) vs Tit-for-Tat
# Match 291/342: Random (0.3) vs Grim Trigger
# Match 292/342: Random (0.3) vs Pavlov
# Match 293/342: Random (0.3) vs Tit-for-Two-Tats
# Match 294/342: Random (0.3) vs Generous Tit-for-Tat
# Match 295/342: Random (0.3) vs Adaptive
# Match 296/342: Random (0.3) vs Always Undercut
# Match 297/342: Random (0.3) vs Suspicious Tit-for-Tat
# Match 298/342: Random (0.3) vs Gradual
# Match 299/342: Random (0.3) vs Prober
# Match 300/342: Random (0.3) vs Hard Majority
# Match 301/342: Random (0.3) vs Soft Majority
# Match 302/342: Random (0.3) vs Random (0.9)
# Match 303/342: Random (0.3) vs Random (0.7)
# Match 304/342: Random (0.3) vs Random (0.5)
# Match 305/342: Random (0.3) vs Random (0.1)
# Match 306/342: Random (0.3) vs Improved Agent
# Match 307/342: Random (0.1) vs Always Invest
# Match 308/342: Random (0.1) vs Tit-for-Tat
# Match 309/342: Random (0.1) vs Grim Trigger
# Match 310/342: Random (0.1) vs Pavlov
# Match 311/342: Random (0.1) vs Tit-for-Two-Tats
# Match 312/342: Random (0.1) vs Generous Tit-for-Tat
# Match 313/342: Random (0.1) vs Adaptive
# Match 314/342: Random (0.1) vs Always Undercut
# Match 315/342: Random (0.1) vs Suspicious Tit-for-Tat
# Match 316/342: Random (0.1) vs Gradual
# Match 317/342: Random (0.1) vs Prober
# Match 318/342: Random (0.1) vs Hard Majority
# Match 319/342: Random (0.1) vs Soft Majority
# Match 320/342: Random (0.1) vs Random (0.9)
# Match 321/342: Random (0.1) vs Random (0.7)
# Match 322/342: Random (0.1) vs Random (0.5)
# Match 323/342: Random (0.1) vs Random (0.3)
# Match 324/342: Random (0.1) vs Improved Agent
# Match 325/342: Improved Agent vs Always Invest
# Match 326/342: Improved Agent vs Tit-for-Tat
# Match 327/342: Improved Agent vs Grim Trigger
# Match 328/342: Improved Agent vs Pavlov
# Match 329/342: Improved Agent vs Tit-for-Two-Tats
# Match 330/342: Improved Agent vs Generous Tit-for-Tat
# Match 331/342: Improved Agent vs Adaptive
# Match 332/342: Improved Agent vs Always Undercut
# Match 333/342: Improved Agent vs Suspicious Tit-for-Tat
# Match 334/342: Improved Agent vs Gradual
# Match 335/342: Improved Agent vs Prober
# Match 336/342: Improved Agent vs Hard Majority
# Match 337/342: Improved Agent vs Soft Majority
# Match 338/342: Improved Agent vs Random (0.9)
# Match 339/342: Improved Agent vs Random (0.7)
# Match 340/342: Improved Agent vs Random (0.5)
# Match 341/342: Improved Agent vs Random (0.3)
# Match 342/342: Improved Agent vs Random (0.1)
# Tournament complete!
#
# ======================================================================
# 📊 TOURNAMENT RESULTS COMPARISON
# ======================================================================
#
# ORIGINAL AGENT:
#   Rank: 12 / 19
#   Total Score: 4,247
#
# IMPROVED AGENT:
#   Rank: 7 / 19
#   Total Score: 4,550
#
# IMPROVEMENT:
#   Rank Change: 5 positions ⬆️
#   Score Change: +303 points (7.1%)
# ======================================================================
#
# 🏆 IMPROVED AGENT TOURNAMENT LEADERBOARD:
# ==================================================
# 🥇  1. Gradual                  : 4,839 points
# 🥈  2. Grim Trigger             : 4,762 points
# 🥉  3. Generous Tit-for-Tat     : 4,727 points
#     4. Tit-for-Tat              : 4,674 points
#     5. Hard Majority            : 4,649 points
#     6. Soft Majority            : 4,623 points
#     7. Improved Agent           : 4,550 points ⭐ YOUR AGENT
#     8. Pavlov                   : 4,506 points
#     9. Adaptive                 : 4,475 points
#    10. Tit-for-Two-Tats         : 4,453 points
#    11. Prober                   : 4,442 points
#    12. Suspicious Tit-for-Tat   : 4,164 points
#    13. Random (0.7)             : 4,087 points
#    14. Always Invest            : 4,071 points
#    15. Random (0.5)             : 3,991 points
#    16. Random (0.9)             : 3,795 points
#    17. Random (0.1)             : 3,644 points
#    18. Always Undercut          : 3,640 points
#    19. Random (0.3)             : 3,579 points

# %%
# ============================================================================
# PART 6: SAVE YOUR AGENT FOR TOURNAMENT (Student customizes & saves)
# ============================================================================

print("\n" + "="*70)
print("💾 SAVE YOUR AGENT FOR UNIT 6 TOURNAMENT")
print("="*70 + "\n")

# TODO: Give your agent a creative name!
my_improved_agent.name = "My Evolved Agent"  # <-- CHANGE THIS!
my_improved_agent.description = "A short description of your agent's general strategy"  # <-- CHANGE THIS!

# Save to JSON file
my_improved_agent.save_to_file("my_tournament_agent.json")

print("\n✅ Next steps:")
print("   1. Download 'my_tournament_agent.json' from this notebook")
print("   2. Submit it for Unit 6 tournament!")
print("   3. Write your reflection on what strategy emerged\n")
# Out:
# ======================================================================
# 💾 SAVE YOUR AGENT FOR UNIT 6 TOURNAMENT
# ======================================================================
#
# ✅ Agent saved to my_tournament_agent.json
#
# ✅ Next steps:
#    1. Download 'my_tournament_agent.json' from this notebook
#    2. Submit it for Unit 6 tournament!
#    3. Write your reflection on what strategy emerged

# %% [markdown]
# ## Post-Evolution Reflection Questions
#
# ### 1. Generalization Analysis
# - Compare your agent's performance on training opponents (📚) vs. unseen opponents (🆕)
# - Did your agent generalize well or overfit to the training set?
# - What does this suggest about evolving against a random sample vs. fixed opponents?
#
# ### 2. Tournament Performance
# - What was your agent's final tournament rank? _____ out of _____
# - What was your agent's total score? _____
# - Look at agents that ranked above and below you - what strategies do they use?
#
# ### 3. Strategy Analysis
# Look at your evolved genes: [____________________]
#
# - In plain English, what strategy did your agent evolve?
# - Does it cooperate with cooperators? Does it punish defectors?
# - Why do you think evolution discovered this particular strategy?
#
# ### 4. Trade-offs
# Every strategy has strengths and weaknesses.
#
# - Which types of opponents does your agent beat?
# - Which types beat your agent?
# - If you could redesign your agent for Unit 6, what would you change?
#
# ### 5. The Environment Matters
# - You evolved against a random sample of 10 opponents
# - The tournament included all 19 opponents
# - Unit 6 will include 30+ student agents with unpredictable strategies
# - How might your agent perform in that different environment?
